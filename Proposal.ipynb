# %%
import pandas as pd

# %% [markdown]
# ## read files

# %%
# whow much fast  linkedin followers grow for each  company
which city is has more spending on education , average price of , living expence,

# %%
from  datetime import datetime
from datetime import date

# %%
ln=pd.read_csv("temp_datalab_records_linkedin_company.zip", compression="zip")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
ln["company_name"].value_counts().sort_values(ascending=False)[:100]
# Out:
# City National Bank               1605
# American Airlines                1029
# Apple                            1025
# Cisco                            1024
# Amgen                            1024
# Activision                       1024
# Comcast                          1023
# Illumina                         1023
# ADP                              1023
# Microsoft                        1023
# Amazon                           1023
# Biogen                           1023
# Facebook                         1023
# Priceline.com                    1022
# DIRECTV                          1022
# Cognizant                        1022
# Google                           1022
# Avago Technologies               1022
# Alexion Pharmaceuticals, Inc.    1022
# The Habit Burger Grill           1022
# Mylan                            1022
# Celgene                          1022
# Ericsson                         1022
# IAC                              1022
# Ctrip.com                        1022
# Intel Corporation                1022
# Gilead Sciences                  1022
# Intuit                           1022
# Avis Budget Group                1022
# Goldman Sachs                    1022
#                                  ...
# Asbury Automotive Group          1020
# Bristol-Myers Squibb             1020
# Scotiabank                       1020
# Cadence Design Systems           1020
# JetBlue Airways                  1020
# CSX                              1020
# General Mills                    1020
# Dean Foods                       1020
# Salesforce                       1020
# Qorvo, Inc.                      1020
# Nasdaq                           1020
# Etsy                             1020
# BlackRock                        1020
# FedEx                            1020
# Duke Energy Corporation          1020
# Fortinet                         1020
# The Walt Disney Company          1020
# GSK                              1020
# GE                               1020
# CME Group                        1020
# Honeywell                        1020
# Dexcom                           1019
# Equinix                          1019
# China Mobile                     1019
# Lowe's Companies, Inc.           1019
# SVB Financial Group              1019
# C.H. Robinson                    1019
# Brown-Forman                     1019
# Brixmor Property Group           1019
# Dollar Tree Stores               1019
# Name: company_name, Length: 100, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cnb=ln[ln["company_name"]=="City National Bank"]

# %%
pd.to_datetimecnb["as_of_date"]

# %%
##jb=pd.read_csv("temp_datalab_records_job_listings.zip",compression="zip")

# %%
fb =pd.read_csv("temp_datalab_records_social_facebook.zip", compression="zip")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
ln.columns
# Out:
# Index(['dataset_id', 'as_of_date', 'company_name', 'followers_count',
#        'employees_on_platform', 'link', 'industry', 'date_added',
#        'date_updated', 'description', 'website', 'entity_id', 'cusip', 'isin'],
#       dtype='object')

# %%
pd.to_datetime(ln.as_of_date)[0]
# Out:
# Timestamp('2015-09-14 00:00:00')

# %%
fcount=ln[ln["company_name"]=="City National Bank"]["followers_count"].reset_index()

# %%
cnb=ln[ln["company_name"]=="City National Bank"]

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1605 entries, 2060 to 2425400
# Data columns (total 14 columns):
# dataset_id               1605 non-null int64
# as_of_date               1605 non-null object
# company_name             1605 non-null object
# followers_count          1605 non-null int64
# employees_on_platform    1605 non-null int64
# link                     1605 non-null object
# industry                 1545 non-null object
# date_added               1605 non-null object
# date_updated             1605 non-null object
# description              305 non-null object
# website                  265 non-null object
# entity_id                0 non-null float64
# cusip                    0 non-null float64
# isin                     0 non-null float64
# dtypes: float64(3), int64(3), object(8)
# memory usage: 268.1+ KB

# %%
date= pd.to_datetime(cnb["as_of_date"]).reset_index()

# %%
date["as_of_date"].apply(lambda x: date.date(x))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-33babec9ce3e> in <module>()
# ----> 1 date["as_of_date"].apply(lambda x: date.date(x))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    2353             else:
#    2354                 values = self.asobject
# -> 2355                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2356
#    2357         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\src\inference.pyx in pandas._libs.lib.map_infer (pandas\_libs\lib.c:66440)()
#
# <ipython-input-69-33babec9ce3e> in <lambda>(x)
# ----> 1 date["as_of_date"].apply(lambda x: date.date(x))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'date'

# %%
type(date["as_of_date"][0])
# Out:
# pandas._libs.tslib.Timestamp

# %%
date.head()
# Out:
# 2060   2015-09-21
# 2560   2015-09-22
# 3075   2015-09-23
# 3607   2015-09-24
# 4140   2015-09-25
# Name: as_of_date, dtype: datetime64[ns]

# %%
cnb.head()
# Out:
#    dataset_id  as_of_date            company_name  followers_count  \
# 0       58329  2015-09-14           Goldman Sachs           552254
# 1       58329  2015-09-15           Goldman Sachs           552862
# 2       58363  2015-09-16     United Technologies            59157
# 3       58366  2015-09-16            Novo Nordisk           336175
# 4       58371  2015-09-16  Lowe's Companies, Inc.           134255
#
#    employees_on_platform                                   link  \
# 0                  38124  https://www.linkedin.com/company/1382
# 1                  38141  https://www.linkedin.com/company/1382
# 2                  14982  https://www.linkedin.com/company/2426
# 3                  26448  https://www.linkedin.com/company/2227
# 4                  62574  https://www.linkedin.com/company/4128
#
#                industry              date_added            date_updated  \
# 0    Investment Banking  2015-09-14 00:00:00+00  2015-09-14 00:00:00+00
# 1    Investment Banking  2015-09-15 00:00:00+00  2015-09-15 00:00:00+00
# 2  Aviation & Aerospace  2015-09-16 00:00:00+00  2015-09-16 00:00:00+00
# 3       Pharmaceuticals  2015-09-16 00:00:00+00  2015-09-16 00:00:00+00
# 4                Retail  2015-09-16 00:00:00+00  2015-09-16 00:00:00+00
#
#   description website  entity_id  cusip  isin
# 0         NaN     NaN        NaN    NaN   NaN
# 1         NaN     NaN        NaN    NaN   NaN
# 2         NaN     NaN        NaN    NaN   NaN
# 3         NaN     NaN        NaN    NaN   NaN
# 4         NaN     NaN        NaN    NaN   NaN

# %%
d=pd.to_datetime(ln[ln["company_name"]=="City National Bank"]['as_of_date']).reset_index()

# %%
plt.plot(d,fcount)
# Out:
# [<matplotlib.lines.Line2D at 0x28c13a9d9b0>,
#  <matplotlib.lines.Line2D at 0x28c13a9dbe0>]

# %%
datetime.timestamp()

# %%
pd.to_datetime("ln")

# %%
ln["company_name"].value_counts().sort_values(ascending=False)
# Out:
# City National Bank                                               1605
# American Airlines                                                1029
# Apple                                                            1025
# Activision                                                       1024
# Cisco                                                            1024
# Amgen                                                            1024
# Microsoft                                                        1023
# Facebook                                                         1023
# Amazon                                                           1023
# Biogen                                                           1023
# ADP                                                              1023
# Comcast                                                          1023
# Illumina                                                         1023
# Cognizant                                                        1022
# IAC                                                              1022
# Ericsson                                                         1022
# Celgene                                                          1022
# DIRECTV                                                          1022
# Avago Technologies                                               1022
# Google                                                           1022
# Starbucks                                                        1022
# Gilead Sciences                                                  1022
# The Habit Burger Grill                                           1022
# Adobe                                                            1022
# Intuit                                                           1022
# Goldman Sachs                                                    1022
# Ctrip.com                                                        1022
# Alexion Pharmaceuticals, Inc.                                    1022
# Intel Corporation                                                1022
# Priceline.com                                                    1022
#                                                                  ...
# Nielsen Latinoamérica                                               1
# H&amp;E Equipment Services, Inc.                                    1
# Sirius XM                                                           1
# BY KILIAN                                                           1
# Titan International, Inc.                                           1
# Nike, Inc.                                                          1
# Innovative Solutions &amp; Support                                  1
# Behr Process Corporation                                            1
# Houston Wire &amp; Cable Company                                    1
# First Mid-Illinois Bank &amp; Trust                                 1
# W&amp;T Offshore                                                    1
# Homeowners Choice Property & Casualty Insurance Company, Inc.       1
# Malvern Federal Savings Bank                                        1
# Xenia Hotels &amp; Resorts                                          1
# ABB Enterprise Software                                             1
# WEATHERFORD SOUTH AMERICA INC.                                      1
# DiscoveryInc                                                        1
# ESSA Bank &amp; Trust                                               1
# Skyscanner                                                          1
# FICO™                                                               1
# ABB’s Enterprise Software Product Group                             1
# ListHub                                                             1
# Wave Life Sciences Ltd.                                             1
# L3 SSG                                                              1
# United Bank & Capital Trust Co.                                     1
# Lexar                                                               1
# eNett International                                                 1
# SeaWorld Parks &amp; Entertainment                                  1
# BNB                                                                 1
# Enterprise Bank &amp; Trust                                         1
# Name: company_name, Length: 5028, dtype: int64

# %%
ln[ln["company_name"]=="City National Bank"]
# Out:
#          dataset_id  as_of_date        company_name  followers_count  \
# 2060          59148  2015-09-21  City National Bank            10831
# 2560          59148  2015-09-22  City National Bank            10840
# 3075          59148  2015-09-23  City National Bank            10848
# 3607          59148  2015-09-24  City National Bank            10858
# 4140          59148  2015-09-25  City National Bank            10868
# 4679          59148  2015-09-26  City National Bank            10880
# 5218          59148  2015-09-27  City National Bank            10883
# 5758          59148  2015-09-28  City National Bank            10896
# 6297          59148  2015-09-29  City National Bank            10901
# 6839          59148  2015-09-30  City National Bank            10906
# 7383          59148  2015-10-01  City National Bank            10912
# 7927          59148  2015-10-02  City National Bank            10922
# 8471          59148  2015-10-03  City National Bank            10921
# 9015          59148  2015-10-04  City National Bank            10925
# 9976          59148  2015-10-06  City National Bank            10934
# 10965         59148  2015-10-08  City National Bank            10952
# 11514         59148  2015-10-09  City National Bank            10958
# 12065         59148  2015-10-10  City National Bank            10966
# 12616         59148  2015-10-11  City National Bank            10972
# 13167         59148  2015-10-13  City National Bank            10990
# 13718         59148  2015-10-14  City National Bank            10997
# 14270         59148  2015-10-15  City National Bank            11008
# 14822         59148  2015-10-16  City National Bank            11013
# 15374         59148  2015-10-17  City National Bank            11021
# 15926         59148  2015-10-18  City National Bank            11022
# 16478         59148  2015-10-19  City National Bank            11030
# 17030         59148  2015-10-20  City National Bank            11039
# 17582         59148  2015-10-21  City National Bank            11054
# 18134         59148  2015-10-22  City National Bank            11061
# 18686         59148  2015-10-23  City National Bank            11071
# ...             ...         ...                 ...              ...
# 2372246       59148  2018-07-03  City National Bank            18012
# 2372388      895852  2018-07-03  City National Bank             2567
# 2375718       59148  2018-07-04  City National Bank            18011
# 2376173      895852  2018-07-04  City National Bank             2570
# 2377586      895852  2018-07-05  City National Bank             2571
# 2379551       59148  2018-07-05  City National Bank            18028
# 2383391       59148  2018-07-06  City National Bank            18033
# 2383795      895852  2018-07-06  City National Bank             2570
# 2386299      895852  2018-07-07  City National Bank             2570
# 2387026       59148  2018-07-07  City National Bank            18037
# 2391359      895852  2018-07-08  City National Bank             2570
# 2392077       59148  2018-07-08  City National Bank            18050
# 2394253      895852  2018-07-09  City National Bank             2570
# 2394520       59148  2018-07-09  City National Bank            18052
# 2397308      895852  2018-07-10  City National Bank             2571
# 2397996       59148  2018-07-10  City National Bank            18065
# 2401671      895852  2018-07-11  City National Bank             2571
# 2403498       59148  2018-07-11  City National Bank            18076
# 2406609      895852  2018-07-12  City National Bank             2572
# 2406997       59148  2018-07-12  City National Bank            18087
# 2408317       59148  2018-07-13  City National Bank            18102
# 2409249      895852  2018-07-13  City National Bank             2572
# 2411391      895852  2018-07-14  City National Bank             2572
# 2412102       59148  2018-07-14  City National Bank            18102
# 2416056      895852  2018-07-15  City National Bank             2577
# 2416318       59148  2018-07-15  City National Bank            18114
# 2419977       59148  2018-07-16  City National Bank            18130
# 2421940      895852  2018-07-16  City National Bank             2578
# 2424095      895852  2018-07-17  City National Bank             2577
# 2425400       59148  2018-07-17  City National Bank            18140
#
#          employees_on_platform                                     link  \
# 2060                      2944  https://www.linkedin.com/company/163069
# 2560                      2948  https://www.linkedin.com/company/163069
# 3075                      2950  https://www.linkedin.com/company/163069
# 3607                      2951  https://www.linkedin.com/company/163069
# 4140                      2952  https://www.linkedin.com/company/163069
# 4679                      2953  https://www.linkedin.com/company/163069
# 5218                      2953  https://www.linkedin.com/company/163069
# 5758                      2960  https://www.linkedin.com/company/163069
# 6297                      2960  https://www.linkedin.com/company/163069
# 6839                      2965  https://www.linkedin.com/company/163069
# 7383                      2967  https://www.linkedin.com/company/163069
# 7927                      2968  https://www.linkedin.com/company/163069
# 8471                      2968  https://www.linkedin.com/company/163069
# 9015                      2969  https://www.linkedin.com/company/163069
# 9976                      2971  https://www.linkedin.com/company/163069
# 10965                     2948  https://www.linkedin.com/company/163069
# 11514                     2949  https://www.linkedin.com/company/163069
# 12065                     2950  https://www.linkedin.com/company/163069
# 12616                     2950  https://www.linkedin.com/company/163069
# 13167                     2941  https://www.linkedin.com/company/163069
# 13718                     2943  https://www.linkedin.com/company/163069
# 14270                     2947  https://www.linkedin.com/company/163069
# 14822                     2947  https://www.linkedin.com/company/163069
# 15374                     2948  https://www.linkedin.com/company/163069
# 15926                     2948  https://www.linkedin.com/company/163069
# 16478                     2949  https://www.linkedin.com/company/163069
# 17030                     2952  https://www.linkedin.com/company/163069
# 17582                     2979  https://www.linkedin.com/company/163069
# 18134                     2979  https://www.linkedin.com/company/163069
# 18686                     2981  https://www.linkedin.com/company/163069
# ...                        ...                                      ...
# 2372246                   4317  https://www.linkedin.com/company/163069
# 2372388                    433  https://www.linkedin.com/company/304330
# 2375718                   4317  https://www.linkedin.com/company/163069
# 2376173                    436  https://www.linkedin.com/company/304330
# 2377586                    436  https://www.linkedin.com/company/304330
# 2379551                   4319  https://www.linkedin.com/company/163069
# 2383391                   4319  https://www.linkedin.com/company/163069
# 2383795                    436  https://www.linkedin.com/company/304330
# 2386299                    436  https://www.linkedin.com/company/304330
# 2387026                   4319  https://www.linkedin.com/company/163069
# 2391359                    436  https://www.linkedin.com/company/304330
# 2392077                   4322  https://www.linkedin.com/company/163069
# 2394253                    436  https://www.linkedin.com/company/304330
# 2394520                   4322  https://www.linkedin.com/company/163069
# 2397308                    437  https://www.linkedin.com/company/304330
# 2397996                   4327  https://www.linkedin.com/company/163069
# 2401671                    437  https://www.linkedin.com/company/304330
# 2403498                   4330  https://www.linkedin.com/company/163069
# 2406609                    437  https://www.linkedin.com/company/304330
# 2406997                   4333  https://www.linkedin.com/company/163069
# 2408317                   4337  https://www.linkedin.com/company/163069
# 2409249                    436  https://www.linkedin.com/company/304330
# 2411391                    436  https://www.linkedin.com/company/304330
# 2412102                   4335  https://www.linkedin.com/company/163069
# 2416056                    440  https://www.linkedin.com/company/304330
# 2416318                   4337  https://www.linkedin.com/company/163069
# 2419977                   4343  https://www.linkedin.com/company/163069
# 2421940                    441  https://www.linkedin.com/company/304330
# 2424095                    441  https://www.linkedin.com/company/304330
# 2425400                   4348  https://www.linkedin.com/company/163069
#
#         industry                     date_added  \
# 2060     Banking         2015-09-21 00:00:00+00
# 2560     Banking         2015-09-22 00:00:00+00
# 3075     Banking         2015-09-23 00:00:00+00
# 3607     Banking         2015-09-24 00:00:00+00
# 4140     Banking         2015-09-25 00:00:00+00
# 4679     Banking         2015-09-26 00:00:00+00
# 5218     Banking         2015-09-27 00:00:00+00
# 5758     Banking         2015-09-28 00:00:00+00
# 6297     Banking         2015-09-29 00:00:00+00
# 6839     Banking         2015-09-30 00:00:00+00
# 7383     Banking         2015-10-01 00:00:00+00
# 7927     Banking         2015-10-02 00:00:00+00
# 8471     Banking         2015-10-03 00:00:00+00
# 9015     Banking         2015-10-04 00:00:00+00
# 9976     Banking         2015-10-06 00:00:00+00
# 10965        NaN         2015-10-08 00:00:00+00
# 11514    Banking         2015-10-09 00:00:00+00
# 12065    Banking         2015-10-10 00:00:00+00
# 12616    Banking         2015-10-11 00:00:00+00
# 13167    Banking         2015-10-13 00:00:00+00
# 13718    Banking         2015-10-14 00:00:00+00
# 14270    Banking         2015-10-15 00:00:00+00
# 14822    Banking         2015-10-16 00:00:00+00
# 15374    Banking         2015-10-17 00:00:00+00
# 15926    Banking         2015-10-18 00:00:00+00
# 16478    Banking         2015-10-19 00:00:00+00
# 17030    Banking         2015-10-20 00:00:00+00
# 17582    Banking         2015-10-21 00:00:00+00
# 18134    Banking         2015-10-22 00:00:00+00
# 18686    Banking         2015-10-23 00:00:00+00
# ...          ...                            ...
# 2372246  Banking  2018-07-03 20:20:03.995322+00
# 2372388  Banking  2018-07-03 13:27:30.270904+00
# 2375718  Banking  2018-07-04 03:31:23.059292+00
# 2376173  Banking  2018-07-04 02:14:42.685648+00
# 2377586  Banking   2018-07-05 12:41:08.48936+00
# 2379551  Banking  2018-07-05 20:39:53.746948+00
# 2383391  Banking  2018-07-06 22:24:58.510461+00
# 2383795  Banking   2018-07-06 20:51:24.13466+00
# 2386299  Banking  2018-07-07 02:14:13.184107+00
# 2387026  Banking   2018-07-07 03:29:26.87463+00
# 2391359  Banking  2018-07-08 20:51:18.284994+00
# 2392077  Banking  2018-07-08 22:52:19.189556+00
# 2394253  Banking  2018-07-09 02:16:55.605976+00
# 2394520  Banking  2018-07-09 03:38:24.429473+00
# 2397308  Banking  2018-07-10 13:22:09.359183+00
# 2397996  Banking  2018-07-10 15:17:05.338193+00
# 2401671  Banking  2018-07-11 13:16:47.336475+00
# 2403498  Banking  2018-07-11 21:49:00.420051+00
# 2406609  Banking  2018-07-12 14:13:42.210167+00
# 2406997  Banking  2018-07-12 16:22:32.978252+00
# 2408317  Banking  2018-07-13 19:35:56.310254+00
# 2409249  Banking  2018-07-13 18:10:55.459907+00
# 2411391  Banking  2018-07-14 02:14:00.170162+00
# 2412102  Banking  2018-07-14 03:28:46.544631+00
# 2416056  Banking   2018-07-15 21:05:02.13857+00
# 2416318  Banking  2018-07-15 22:25:55.303834+00
# 2419977  Banking  2018-07-16 23:51:24.632679+00
# 2421940  Banking    2018-07-16 17:44:34.5144+00
# 2424095  Banking  2018-07-17 13:54:36.691543+00
# 2425400  Banking  2018-07-17 19:56:44.294867+00
#
#                           date_updated description                    website  \
# 2060            2015-09-21 00:00:00+00         NaN                        NaN
# 2560            2015-09-22 00:00:00+00         NaN                        NaN
# 3075            2015-09-23 00:00:00+00         NaN                        NaN
# 3607            2015-09-24 00:00:00+00         NaN                        NaN
# 4140            2015-09-25 00:00:00+00         NaN                        NaN
# 4679            2015-09-26 00:00:00+00         NaN                        NaN
# 5218            2015-09-27 00:00:00+00         NaN                        NaN
# 5758            2015-09-28 00:00:00+00         NaN                        NaN
# 6297            2015-09-29 00:00:00+00         NaN                        NaN
# 6839            2015-09-30 00:00:00+00         NaN                        NaN
# 7383            2015-10-01 00:00:00+00         NaN                        NaN
# 7927            2015-10-02 00:00:00+00         NaN                        NaN
# 8471            2015-10-03 00:00:00+00         NaN                        NaN
# 9015            2015-10-04 00:00:00+00         NaN                        NaN
# 9976            2015-10-06 00:00:00+00         NaN                        NaN
# 10965           2015-10-08 00:00:00+00         NaN                        NaN
# 11514           2015-10-09 00:00:00+00         NaN                        NaN
# 12065           2015-10-10 00:00:00+00         NaN                        NaN
# 12616           2015-10-11 00:00:00+00         NaN                        NaN
# 13167           2015-10-13 00:00:00+00         NaN                        NaN
# 13718           2015-10-14 00:00:00+00         NaN                        NaN
# 14270           2015-10-15 00:00:00+00         NaN                        NaN
# 14822           2015-10-16 00:00:00+00         NaN                        NaN
# 15374           2015-10-17 00:00:00+00         NaN                        NaN
# 15926           2015-10-18 00:00:00+00         NaN                        NaN
# 16478           2015-10-19 00:00:00+00         NaN                        NaN
# 17030           2015-10-20 00:00:00+00         NaN                        NaN
# 17582           2015-10-21 00:00:00+00         NaN                        NaN
# 18134           2015-10-22 00:00:00+00         NaN                        NaN
# 18686           2015-10-23 00:00:00+00         NaN                        NaN
# ...                                ...         ...                        ...
# 2372246   2018-07-03 20:20:03.99537+00         NaN         http://www.cnb.com
# 2372388  2018-07-03 13:27:30.270954+00         NaN  http://www.bankatcity.com
# 2375718  2018-07-04 03:31:23.059358+00         NaN         http://www.cnb.com
# 2376173  2018-07-04 02:14:42.685691+00         NaN  http://www.bankatcity.com
# 2377586   2018-07-05 12:41:08.48939+00         NaN  http://www.bankatcity.com
# 2379551  2018-07-05 20:39:53.746997+00         NaN         http://www.cnb.com
# 2383391  2018-07-06 22:24:58.510504+00         NaN         http://www.cnb.com
# 2383795  2018-07-06 20:51:24.134687+00         NaN  http://www.bankatcity.com
# 2386299  2018-07-07 02:14:13.184193+00         NaN  http://www.bankatcity.com
# 2387026  2018-07-07 03:29:26.874727+00         NaN         http://www.cnb.com
# 2391359  2018-07-08 21:09:10.630651+00         NaN  http://www.bankatcity.com
# 2392077  2018-07-08 22:52:19.189599+00         NaN         http://www.cnb.com
# 2394253  2018-07-09 02:16:55.606021+00         NaN  http://www.bankatcity.com
# 2394520  2018-07-09 03:38:24.429517+00         NaN         http://www.cnb.com
# 2397308  2018-07-10 13:22:09.359231+00         NaN  http://www.bankatcity.com
# 2397996   2018-07-10 15:17:05.33824+00         NaN         http://www.cnb.com
# 2401671  2018-07-11 13:16:47.336507+00         NaN  http://www.bankatcity.com
# 2403498    2018-07-11 21:49:00.4201+00         NaN         http://www.cnb.com
# 2406609  2018-07-12 14:13:42.210194+00         NaN  http://www.bankatcity.com
# 2406997  2018-07-12 16:22:32.978296+00         NaN         http://www.cnb.com
# 2408317  2018-07-13 19:35:56.310276+00         NaN         http://www.cnb.com
# 2409249  2018-07-13 18:10:55.459945+00         NaN  http://www.bankatcity.com
# 2411391  2018-07-14 02:14:00.170206+00         NaN  http://www.bankatcity.com
# 2412102  2018-07-14 03:28:46.544677+00         NaN         http://www.cnb.com
# 2416056   2018-07-15 21:05:02.13861+00         NaN  http://www.bankatcity.com
# 2416318  2018-07-15 22:25:55.303877+00         NaN         http://www.cnb.com
# 2419977    2018-07-16 23:51:24.6327+00         NaN         http://www.cnb.com
# 2421940  2018-07-16 17:44:34.514447+00         NaN  http://www.bankatcity.com
# 2424095  2018-07-17 13:54:36.691594+00         NaN  http://www.bankatcity.com
# 2425400   2018-07-17 19:56:44.29489+00         NaN         http://www.cnb.com
#
#          entity_id  cusip  isin
# 2060           NaN    NaN   NaN
# 2560           NaN    NaN   NaN
# 3075           NaN    NaN   NaN
# 3607           NaN    NaN   NaN
# 4140           NaN    NaN   NaN
# 4679           NaN    NaN   NaN
# 5218           NaN    NaN   NaN
# 5758           NaN    NaN   NaN
# 6297           NaN    NaN   NaN
# 6839           NaN    NaN   NaN
# 7383           NaN    NaN   NaN
# 7927           NaN    NaN   NaN
# 8471           NaN    NaN   NaN
# 9015           NaN    NaN   NaN
# 9976           NaN    NaN   NaN
# 10965          NaN    NaN   NaN
# 11514          NaN    NaN   NaN
# 12065          NaN    NaN   NaN
# 12616          NaN    NaN   NaN
# 13167          NaN    NaN   NaN
# 13718          NaN    NaN   NaN
# 14270          NaN    NaN   NaN
# 14822          NaN    NaN   NaN
# 15374          NaN    NaN   NaN
# 15926          NaN    NaN   NaN
# 16478          NaN    NaN   NaN
# 17030          NaN    NaN   NaN
# 17582          NaN    NaN   NaN
# 18134          NaN    NaN   NaN
# 18686          NaN    NaN   NaN
# ...            ...    ...   ...
# 2372246        NaN    NaN   NaN
# 2372388        NaN    NaN   NaN
# 2375718        NaN    NaN   NaN
# 2376173        NaN    NaN   NaN
# 2377586        NaN    NaN   NaN
# 2379551        NaN    NaN   NaN
# 2383391        NaN    NaN   NaN
# 2383795        NaN    NaN   NaN
# 2386299        NaN    NaN   NaN
# 2387026        NaN    NaN   NaN
# 2391359        NaN    NaN   NaN
# 2392077        NaN    NaN   NaN
# 2394253        NaN    NaN   NaN
# 2394520        NaN    NaN   NaN
# 2397308        NaN    NaN   NaN
# 2397996        NaN    NaN   NaN
# 2401671        NaN    NaN   NaN
# 2403498        NaN    NaN   NaN
# 2406609        NaN    NaN   NaN
# 2406997        NaN    NaN   NaN
# 2408317        NaN    NaN   NaN
# 2409249        NaN    NaN   NaN
# 2411391        NaN    NaN   NaN
# 2412102        NaN    NaN   NaN
# 2416056        NaN    NaN   NaN
# 2416318        NaN    NaN   NaN
# 2419977        NaN    NaN   NaN
# 2421940        NaN    NaN   NaN
# 2424095        NaN    NaN   NaN
# 2425400        NaN    NaN   NaN
#
# [1605 rows x 14 columns]

# %%
ln.description.value_counts()
# Out:
# Aon plc (NYSE:AON) is a leading global professional services firm providing a broad range of risk, retirement and health solutions. Our 50,000 colleagues in 120 countries empower results for clients by using proprietary data and analytics to deliver insights that reduce volatility and improve performance.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                306
# As a market leader and global supplier of advanced micro-acoustic, audio processing, and specialty component solutions, serving the mobile consumer electronics, communications, medical, military, aerospace, and industrial markets, Knowles has achieved excellence for nearly 70 years. We strive to continuously reinvent our industry, and develop technology that improves the audio experience. Today, Knowles products are used by more than one billion people worldwide every day, enhancing how they interact with the world around them. \r\n\r\nHeadquartered in Itasca, Illinois, Knowles has nearly 12,000 employees across 15 countries, including more than 800 engineers dedicated to pioneering acoustics and audio technology. This R&D investment, coupled with our state-of-the-art manufacturing facilities around the world, enable us to deliver advanced MEMS microphones, balanced armature speakers, voice processing and algorithms, and capacitors and timing devices. \r\n\r\nWe see possibility in unexpected places, and are unified by a spirit of innovation to constantly push boundaries, drive the industry forward and enable people to experience improved voice and audio quality in every facet of their lives. We transform the way people communicate, interact with technology and enjoy sound. We are Knowles.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     244
# IPG Photonics is the world leader in high-power fiber lasers, fiber amplifiers, hybrid fiber/solid-state lasers and diode lasers for use in a wide range of markets including materials processing, advanced technologies, telecommunications & medical applications. IPG manufactures fiber lasers operating at 0.5 – 5 microns. IPG’s 1um and 1.5um fiber lasers and amplifiers are particularly popular in single-frequency and linearly-polarized variants; providing products having the best available combination of performance, reliability and price. IPG's newly developed 2-5 microns mid-IR lasers offer cost-effective solutions for sensing, spectroscopy, material processing & medical applications.\r\n\r\nFounded in 1990, IPG Photonics pioneered the development and commercialization of optical fiber-based lasers, a new generation of lasers that combine the advantages of semiconductor diodes with the high amplification and precise beam qualities of specialty optical fibers. Fiber lasers deliver superior performance, reliability and usability at a lower total cost of ownership than conventional lasers and 15x more energy efficient than conventional lasers.\r\n\r\nIPG's fully vertically integrated manufacturing process provides significant competitive advantages and enhances its ability to meet customer requirements, manage costs and improve performance. IPG Photonics is headquartered in Oxford, MA with additional manufacturing and application facilities worldwide including Germany, Italy and Russia.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              153
# ScanSource, Inc. (NASDAQ: SCSC) is a leading global provider of technology products and solutions, focusing on point-of-sale, barcode, physical security, video, voice, data networking and technology services.  ScanSource’s teams provide value-added solutions and operate from two segments, Worldwide Barcode and Security and World Communications and Services. ScanSource is committed to helping its resellers and sales partners choose, configure, and deliver the industry’s best solutions across almost every vertical market in North America, Latin America, and Europe. In August 2016, ScanSource entered the recurring revenue telecom and cloud services market through its acquisition of Intelisys, the industry’s leading technology services distributor. Founded in 1992, ScanSource is headquartered in Greenville, South Carolina and was named one of the 2016 Best Places to Work in South Carolina. ScanSource ranks #685 on the Fortune 1000. For more information, please visit www.scansource.com.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              153
# At United, we are committed to providing each customer with an unmatched level of service. While we offer competitive products, services, rates, and technology, the level of service we provide and our commitment to building relationships is what sets us apart from our competitors.  \r\n\r\nUnited isn’t just growing to get bigger. We are growing to satisfy the continued demand for a bank that focuses on service. With 130 branches across Maryland, Ohio, Pennsylvania, Virginia and West Virginia and over 1600 employees, our mix of competitive products, combined with a high level of service and a focus on relationships is an overwhelming value proposition for our customers.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             153
# First Niagara is now part of KeyBank. Stay up to date with company news and career opportunities by connecting with us on the KeyBank page. For more information, visit us here: http://bit.ly/2d8Pq58.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           153
# We are leading the gene therapy revolution. Our integrated product platforms encompass gene therapy, cancer immunotherapy and gene editing – providing us with the potential to treat, and hopefully cure, a broad range of serious diseases.\r\n\r\nWe have a lot of energy, and it’s not just the abundance of coffee that keeps us going. Find out what sparks our excitement and inspires us every day.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       153
# Cidara is a biotechnology company focused on the discovery, development, and commercialization of novel anti-infectives for the treatment of diseases that are inadequately addressed by current standard of care therapies. Our lead product candidate is CD101 IV, a potential once-weekly intravenous therapy being developed for the treatment and prevention of systemic fungal infections. In addition, we have developed a proprietary immunotherapy technology platform, Cloudbreak™, which we use to create compounds designed to direct a patient’s immune cells to attack and eliminate pathogens that cause infectious disease. CD201 is our lead Cloudbreak candidate intended to direct a patient’s immune cells to attack bacterial infections.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    153
# EMC Insurance Companies is among the top 50 insurance organizations in the country based on net written premium, and we have more than 2,100 employees. The company was organized in 1911 to write workers’ compensation protection in Iowa. Today, EMC provides property and casualty insurance products and services throughout the United States and writes reinsurance contracts worldwide. Operating under the trade name EMC Insurance Companies, Employers Mutual Casualty Company and one or more of its affiliated companies is licensed in all 50 states and the District of Columbia.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  153
# Thixoforming, a division of ARC Group Worldwide, specializes in the Thixomolding process. This process produces high density, complex injection molded components from magnesium alloys. Thixomolding combines the design and processing flexibility of plastic injection molding with the strength produced by high-pressure diecasting. Compared with conventional diecasting, Thixo produces components with greater detail, improved metallurical structure and tolerance capability. In addition, Thixomolding offers greater strength and thin wall capability compared to plastic injection molded applications.\r\n\r\nARC Group Worldwide is a leading global advanced manufacturing and 3D printing provider. ARC offers its customers a compelling portfolio of cutting-edge manufacturing capabilities to improve efficiency of traditional manufacturing processes. For more information about ARC Group Worldwide and to see how Advanced Forming Technology fits into this innovative manufacturing company, visit www.arcgroupworldwide.com                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       153
# Campbell Soup Company (NYSE:CPB) is a global food company headquartered in Camden, N.J., with annual sales of approximately $8 billion. The Company makes a range of high-quality soups and simple meals, beverages, snacks and packaged fresh foods. Campbell is driven and inspired by our purpose: Real food that matters for life’s moments. For generations, people have trusted Campbell to provide authentic, flavorful and readily available foods and beverages that connect them to each other, to warm memories, and to what’s important today.\r\n\r\nLed by our iconic $2.1 billion Campbell’s brand, our portfolio extends beyond soup to foods such as Pepperidge Farm cookies and Goldfish crackers; Arnott’s, Kjeldsens and Royal Dansk biscuits; V8 beverages; Bolthouse Farms super-premium beverages, carrots and dressings; Garden Fresh Gourmet’s salsas, chips and hummus; Plum premium organic baby food;Swanson broths; Prego pasta sauces; and Pace Mexican sauce.\r\n\r\n\r\nCAMPBELL SOUP COMPANY\r\nwww.campbellsoupcompany.com \r\nCampbell Valuing People, People Valuing Campbell \r\nCampbell Soup Company is an Equal Opportunity Employer                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      153
# Ubiquiti Networks, Inc. (Nasdaq: UBNT) eliminates barriers to connectivity for under-networked enterprises, communities and consumers with its leading-edge platforms that connect hundreds of millions of people throughout the world.  With over 60 million devices sold worldwide, through a network of over 100 distributors, to customers in more than 180 countries and territories, Ubiquiti has maintained an industry-leading financial profile by leveraging a unique business model to develop products that combine innovative technology with disruptive price-to-performance characteristics.  Our growth is supported by the Ubiquiti Community, a global grass-roots community of 4 million entrepreneurial operators and systems integrators who engage in thousands of forums.  For more information, join our community at http://www.ubnt.com.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                153
# Big 5 Sporting Goods is one of America's top retailers of name brand sporting goods and accessories. Operating over 430 stores in 11 western states, Big 5 provides a full-line product offering in a traditional sporting goods store format that averages approximately 11,000 square feet. Big 5's product mix includes athletic shoes, apparel and accessories, as well as a broad selection of outdoor and athletic equipment for team sports, fitness, camping, hunting, fishing, tennis, golf, and in-line skating.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        153
# Middlesex Water Company (NASDAQ:MSEX) provides a full range of regulated and non-regulated water, wastewater utility and related services in parts of New Jersey, Delaware and Pennsylvania. Middlesex Water engages in collecting, treating, distributing and selling water for domestic, commercial, municipal, industrial and fire protection purposes. Through its comprehensive suite of services including its latest offering -- turnkey renewable energy services,  the Middlesex Water family of companies provide customers, small system owners, developers and municipalities with practical water and wastewater solutions that enhance quality of life and serve as the framework for economic development.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         153
# Vanda is a specialty pharmaceutical company focused on the development and commercialization of novel therapies to address high unmet medical needs and improve the lives of patients.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            153
# Our firm is characterized by conservative business principles and a policy of putting safety first, building solid relationships with self-directed individual investors and corporate and institutional clients through exceptional personal service and proven performance. Serving investors with integrity and respect for more than 45 years, Muriel Siebert & Co., Inc., is a wholly-owned subsidiary of Siebert Financial Corp., (Nasdaq: SIEB) and a certified Women’s Business Enterprise. \r\n\r\nFor over 45 years we’ve put the focus where it belongs. On you. Expect the personal attention of a fine boutique with the products, stability and resources of a world-class brokerage firm – all at one fair commission charge with no hidden fees. To negotiate a commission schedule or margin rates, or for additional information about Siebert Financial and our products and services, we welcome you to visit us at www.SiebertNet.com                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        153
# The Fauquier Bank, established in 1902, is an independent, locally-owned community bank offering a full range of financial services for commercial and retail customers including internet banking, insurance, wealth management and financial planning through its banking offices located in Fauquier and Prince William Counties in Virginia.\r\n\r\nFor over a century, TFB has built its reputation on trust and sound business judgment.  As a full-service financial institution, we provide quality banking and wealth management products for businesses and families.\r\n\r\nMember FDIC.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               153
# Iowa farmer Arthur Luscombe founded Art’s Way Manufacturing in 1956, to produce and sell a PTO powered grinder mixer he developed on his farm near Dolliver, Iowa. His first product was a great success that marked the beginning of his amazing career as an inventor and entrepreneur. In 1959, Luscombe moved the company from his original plant in downtown Armstrong to its present location, and the grinder mixer line was expanded to include OEM work for companies such as Massey Ferguson, Owatonna and Case or as it was known then, International Harvester.\r\n\r\nToday, Art’s Way has approximately 200 employees and operates its 4 business units in 7 facilities. Arthur Luscombe’s dedication to innovation, quality and durability remains the central focus of our products and business practices. We take pride in the quality of our grinder mixers, sugar beet harvesters, graders, plows and other farm machinery, and continue to expand our product lines to meet the needs of our customers.\r\n\r\nTo view the career opportunities currently open at Art's Way Manufacturing Co., Inc., visit:  http://www.artsway-mfg.com/the-company/careers/                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 153
# At CBS EcoMedia Inc., we have a vision: To harness the power of advertising and channel it into tangible social change.\r\n\r\nSince the founding of the company in 2001, our team has worked tirelessly to develop and hone an advertising model that would transform this ideal into reality.\r\n\r\nIt was with great pride that in 2011 and 2012, we launched our EcoAd, WellnessAd, and EducationAd programs.  These unique product offerings are based on our patent-pending ad model through which our clients, in collaboration with our wide network of non-profit partners, provide financial support for critical, yet underfunded, environmental, health, and education projects in communities nationwide.\r\n\r\nWith the company’s 2010 acquisition by CBS, we exponentially scaled our reach. EcoMedia is now proud to offer our clients the opportunity to communicate their messages across all CBS platforms – national television, local television, radio, outdoor, and interactive.\r\n\r\nWe’re honored and gratified to have been recognized for our work in social enterprise. In 2009, we received the United States Conference of Mayors’ Excellence in Public/Private Partnerships Award. In 2012 and 2013, we have been an Edison Award winner for social innovation.\r\n\r\nBut the greatest reward of all? The ability to make a significant, positive impact in the communities we serve.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         153
# Universal Display Corporation (Nasdaq: OLED) is lighting up the OLED revolution with its proprietary OLED technologies and phosphorescent materials. The Company is a world-class IP innovator, technology developer, patent licensor and materials supplier for the rapidly growing OLED markets. We are a leader in developing and delivering state-of-the-art, organic light emitting diode (OLED) technologies, materials and services to the display and lighting industries. \n\nFounded in 1994, the Company currently owns or has exclusive, co-exclusive or sole license rights with respect to more than 4,200 issued and pending patents worldwide. Universal Display licenses its proprietary technologies, including its breakthrough high-efficiency UniversalPHOLED® phosphorescent OLED technology, that can enable the development of low power and eco-friendly displays and lighting. The Company also develops and offers high-quality, state-of-the-art UniversalPHOLED materials that are recognized as key ingredients in the fabrication of OLEDs with peak performance. In addition, Universal Display delivers innovative and customized solutions to its clients and partners through technology transfer, collaborative technology development and on-site training.\n\nUniversal Display has established relationships with companies such as AU Optronics Corporation, BOE Technology, DuPont Displays, Inc., Innolux Corporation, Kaneka Corporation, Konica Minolta Technology Center, Inc., LG Display Co., Ltd., Lumiotec, Inc., OLEDWorks LLC, OSRAM, Pioneer Corporation, Samsung Display Co., Ltd., Sumitomo Chemical Company, Ltd., Tianma Micro-electronics Co., and Tohoku Pioneer Corporation. To learn more about Universal Display Corporation, please visit http://www.oled.com.                                                                                                                                                                                                                                                                                      153
# CyrusOne (NASDAQ: CONE) specializes in highly reliable enterprise-class, carrier-neutral data center properties. The company provides mission-critical data center facilities that protect and ensure the continued operation of IT infrastructure for nearly 900 customers, including nearly half of the Fortune 20 and more than 160 of the Fortune 1000 or equivalent-sized companies.\r\n\r\nCyrusOne’s data center offerings provide the flexibility, reliability, and security that enterprise customers require and are delivered through a tailored, customer service-focused platform designed to foster long-term relationships. CyrusOne’s National IX platform provides robust connectivity options to drive revenue, reduce expenses, and improve service quality for enterprises, content, and telecommunications companies. CyrusOne is committed to full transparency in communication, management, and service delivery throughout its more than 30 data centers worldwide.\r\n\r\nIf you would like to learn about career opportunities at CyrusOne, we encourage you to review our current list of open positions: http://bit.ly/C1Careers\r\n\r\nTake a virtual tour of CyrusOne facilities here: http://www.cyrusone.com/data-center-locations/data-center-virtual-tours/                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    153
# Energy Focus, Inc. is a leading provider of energy efficient LED lighting products and technology. Our LED lighting products provide energy savings, aesthetics, safety and maintenance cost benefits over conventional lighting that can save companies up to 75% of their lighting energy costs. Our long-standing relationship with the U.S. Government continues to enable us to provide energy efficient LED lighting products to the U.S. Navy and the Military Sealift Command fleets.\n\nCustomers include national, state and local U.S. government agencies as well as Fortune 500 companies, the U.S. Navy, and many others. Company headquarters are located in Solon, OH. For more information, see our web site at www.energyfocus.com.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             153
# Stay Local Go Far\n\nUnion Bank, a wholly-owned subsidiary of Union Bankshares, Inc. (UNB, traded on the NASDAQ Exchange), provides commercial, retail and municipal banking services and asset management services throughout northern Vermont and New Hampshire. Union Bank operates 17 banking offices, three loan centers, and multiple ATMs throughout its geographical footprint.\n\nUnion Bank has been helping people buy homes and local businesses create jobs in area communities since opening its doors over 125 years ago. Union Bank has earned an exceptional reputation for residential lending programs and has recently been named, for the fourth consecutive year, the USDA RD Vermont lender of the year. Union Bank is also an SBA Preferred lender. Proud to be one of the few community banks serving Vermont and New Hampshire, Union Bank maintains a strong commitment to traditional values.  Union Bank is dedicated to providing genuine customer service and community support and donates to various local nonprofits annually.  These values-combined with financial expertise, quality products and the latest technology- make Union Bank the leading choice for your banking services, both personal and commercial.\n\nWe invite you to take advantage of our local insight!\n\n800.753.4343\n\n© 2017 Union Bank.\nMember FDIC, Equal Housing Lender                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       153
# ...
# Primo Water was founded in 2004 by Billy Prim, a successful entrepreneur and the founder of Blue Rhino, the market leader in propane grill cylinder exchange. Using the Blue Rhino model, Billy created Primo Water as a way to offer consumers both innovative, stylish water dispensers for the home and office and clean, great tasting purified water using Refill and Exchange processes that are affordable, convenient options to give your family great tasting, premium water without creating waste in the environment. As America's #1 water dispenser brand, Primo is an environmentally and ethically responsible company dedicated to producing products that will help people live healthier and save money.\n\nFor more information and to learn more about Primo Water, please visit our website at www.primowater.com\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           1
# Arctic Silicon Devices (ASD) is a privately held company based in Trondheim, Norway. ASD was founded in 2007 by a group of former colleagues at Nordic Semiconducter.   The group existed as a department of Nordic Semiconductor from 1998 until 2007, and specialized in building high speed, high accuracy pipline ADC data converters. The main business model was selling intellectual property cores.  The current business model in ASD is to be a fab-less semiconductor company, building standard components. During the tree first years, ASD has launched 4 product families with around 30 different products and speed grades.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# TubeMogul, now part of Adobe, is the leading software company for brand advertising. \n\nTubeMogul’s advertising software enables the world’s largest brands to streamline their global, cross-channel advertising from a single platform. By improving transparency and leveraging real-time data, our software provides holistic planning tools, analytics and insights across television, video, display, mobile, social and other brand advertising initiatives.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
# RealPage is a leading global provider of software and data analytics to the real estate industry. Clients use our platform to improve operating performance and increase capital returns. Founded in 1998 and headquartered in Richardson, Texas, RealPage currently serves nearly 11,500 clients worldwide from offices in North America, Europe and Asia. For more information about the company, visit https://www.realpage.com.\n\nIndustry verticals:  Conventional, Enterprise, Institutional, Affordable HUD, Student Living, Military Housing, Tax Credit, Senior Living, Single Family, Vacation Rentals\n\nFollow us on Twitter: https://twitter.com/RealPage\nLike us on Facebook:  https://www.facebook.com/realpage\nFollow us on Instagram: https://www.instagram.com/realpageinc\n\n#Work4RP                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         1
# Blacksmith Applications is a SaaS technology company offering TPM software and consulting to top tier CPG retail and foodservice organizations. Our application, FORGE, enables program creation, claim settlement, and boasts powerful analytical capabilities. Our customer list includes organizations such as General Mills, Unilever Food Solutions, Conagra Brands, The KraftHeinz Company and more. The Blacksmith Applications team is comprised of professionals with decades of CPG experience and we stand apart from ordinary solutions not only in the capabilities of our application but also in our industry knowledge.  Our commitment to helping the industry improve trade processes and strategy includes the creation and maintenance of a share-group: Smoke Jumpers. Twice a year, senior personnel from top CPG companies gather together to discuss industry change.  OUR APPLICATION  |  FORGE  What it Does:  Create programs, settle claims and gain insights. FORGE enables your team to automate workflows and speed the go-to-market approach, moving cases and settling claims faster than ever before.  Who it Helps:   CPG companies spending millions of dollars in trade on an annual basis. Finance, Sales, Marketing and IT professionals can all benefit from the application to speed workflows and make smart fiscal decisions.  Addressable Channels:  The application easily manages trade spend activity related to Foodservice, Traditional Retail, In-Store Deli, Grocery Perimeter, C Store, Institutional, Export and Club & Mass Merch.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
# Fuwei Films (Holdings) Co., Ltd. ("Fuwei Films" or the "Company") was formed in August 2004. Fuwei Films conducts its business operations through its wholly owned subsidiary Fuwei Films (Shandong) Co., Ltd. ("Shandong Fuwei").   We develop, manufacture and distribute high quality plastic film using the biaxial oriented stretch technique, otherwise known as BOPET film (biaxially oriented polyethylene terephthalate). The film is suitable for many forms of flexible packaging, printing, laminating, aluminum-plating and other applications. In addition, it retains high dielectric strength and volume resistance even at high temperatures, which are essential qualities for electrical and electronic uses. Our BOPET film is widely used in consumer based packaging (such as the food, pharmaceutical, cosmetics, tobacco and alcohol industries), imaging (such as masking film, printing plates and microfilms), electronics and electrical industries (such as wire and cable wrap, capacitors and motor insulation), as well as in magnetic products (such as audio and video tapes). We market our products under our brand name “Fuwei Films.” Our customers include some of the world’s largest companies engaged in flexible packaging, including Alcan, Inc. of Canada. We also export our products to packaging customers and distributors in the US, Japan and Southeast Asia.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
# Rexford Industrial (NYSE: REXR) is a real estate investment trust focused on owning and operating industrial properties in Southern California in-fill markets.  The Company owns interests in 139 properties with approximately 16.2 million rentable square feet and manages an additional 19 properties with approximately 1.2 million rentable square feet.\n\nFor additional information, visit www.rexfordindustrial.com.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
# Name: description, Length: 5386, dtype: int64

# %%
s=ln[ln["industry"]=="Investment Banking"]["company_name"].unique()

# %%
inter=set(ln["company_name"]).intersection(set(fb["username"]))

# %% [markdown]
# ## FAcebook

# %%
fb.info() # info about the data fram
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3621391 entries, 0 to 3621390
# Data columns (total 14 columns):
# dataset_id             int64
# time                   object
# username               object
# checkins               int64
# has_added_app          object
# were_here_count        int64
# likes                  int64
# talking_about_count    int64
# facebook_id            int64
# date_added             object
# date_updated           object
# entity_id              float64
# cusip                  float64
# isin                   float64
# dtypes: float64(3), int64(6), object(5)
# memory usage: 386.8+ MB

# %%
fb.columns
# Out:
# Index(['dataset_id', 'time', 'username', 'checkins', 'has_added_app',
#        'were_here_count', 'likes', 'talking_about_count', 'facebook_id',
#        'date_added', 'date_updated', 'entity_id', 'cusip', 'isin'],
#       dtype='object')

# %%
fb.head()
# Out:
#    dataset_id                    time              username  checkins  \
# 0       53088  2015-01-01 05:00:00+00            SodaStream         0
# 1       52642  2015-01-01 05:00:00+00              ANSYSInc       148
# 2       53656  2015-01-01 05:00:00+00         MyAquaAmerica         0
# 3       53033  2015-01-01 05:00:00+00              Qualcomm       173
# 4       52783  2015-01-01 05:00:00+00  eaglepharmaceuticals         0
#
#   has_added_app  were_here_count    likes  talking_about_count  \
# 0             f                0   761533                  587
# 1             f                0    43442                 1305
# 2             f                0     5591                  297
# 3             f                0  1232521                 2685
# 4             f                0       18                    0
#
#         facebook_id date_added                   date_updated  entity_id  \
# 0       54885616308        NaN  2017-02-14 03:35:13.236826+00        NaN
# 1   160242297413411        NaN   2017-02-14 01:55:52.78506+00        NaN
# 2   591693544195818        NaN  2017-02-14 08:13:51.267343+00        NaN
# 3      108472637291        NaN  2017-02-14 03:24:04.363035+00        NaN
# 4  1428265940729350        NaN  2017-02-14 02:22:10.193588+00        NaN
#
#    cusip  isin
# 0    NaN   NaN
# 1    NaN   NaN
# 2    NaN   NaN
# 3    NaN   NaN
# 4    NaN   NaN

# %%
fb["username"].value_counts().sort_values(ascending=False)
# Out:
# aflacduck                     1222
# RedRobin                      1222
# 2u                            1222
# SPG                           1222
# shutterfly                    1222
# TiVo                          1222
# ModelNInc                     1222
# stamps.com                    1221
# MercBank                      1221
# telenav                       1221
# atmosenergy                   1221
# EchoStar                      1221
# ford                          1221
# gopro                         1221
# GrandCanyonU                  1221
# SynacorInc                    1221
# MurphyUSA                     1221
# ApacheCorporation             1221
# BancorpSouthStudents          1221
# Costco                        1221
# lumberliquidators             1221
# petropoints                   1221
# MicrovisionInc                1221
# ZoesKitchen                   1221
# merrimackpharma               1221
# SodaStream                    1221
# ColumbiaSportswear            1221
# travelers                     1221
# generalmotors                 1221
# CDWCorporation                1221
#                               ...
# OneKBR                           3
# BrinksHomeSec                    3
# gerdau                           2
# KBRcorp                          2
# cbssportingclub                  2
# LeeRiders                        2
# Verizonfios                      2
# DiscoveryCove                    2
# nteloswireless                   2
# thoughtcocom                     2
# InterGlobeTechnologies           2
# TKMaxxAustria                    2
# CambrexCorporation               2
# AviancaCo                        2
# ncmmedianetworks                 1
# BuschGardensVa                   1
# GlobalPayInc                     1
# mclartynissannlr                 1
# blackanddecker                   1
# corporateexecutiveboard          1
# MobankKC                         1
# ExperimentswithGoogle            1
# Lasuavecita104.3                 1
# mclartymazda                     1
# mclartynissanlr                  1
# AlexanderMarineSD                1
# InvesetmentTechnologyGroup       1
# VivintSolarAlbany                1
# Lifetime.Life                    1
# AmericanNationalHomeOffice       1
# Name: username, Length: 4950, dtype: int64

# %%
fb["time"][0] #  see the format of the time
# Out:
# '2015-01-01 05:00:00+00'

# %%
#extract year , month and date
def get_year_mon_day(date):
    date= str(date) # convert to string 
    splited= date.split("-") # to get month, day, and year and time
    year= splited[0] # get year 
    month=splited[1]
    day= splited[2][:2] # extract only the day
    return year, month ,day

# %%
def get_year(date):
    date= str(date) # convert to string 
    splited= date.split("-") # to get month, day, and year and time
    year= splited[0] # get year 
    return year

def get_month(date):
    date= str(date) # convert to string 
    splited= date.split("-") # to get month, day, and year and time
    month= splited[1] # get year 
    return month
def get_day(date):
    date= str(date) # convert to string 
    splited= date.split("-") # to get month, day, and year and time
    day= splited[2][:2] # extract only the day, month ,day
    return

# %%
a,b, c=get_year_mon_day(fb["time"][0])
b
# Out:
# '01'

# %%
get_year_mon_day(fb["time"][0])

# %%
fb["time"].apply(get_year_mon_day).values
# Out:
# array([('2015', '01', '01'), ('2015', '01', '01'), ('2015', '01', '01'),
#        ..., ('2018', '07', '17'), ('2018', '07', '17'),
#        ('2018', '07', '17')], dtype=object)

# %%
df[['column_new_1', 'column_new_2', 'column_new_3']] = pd.DataFrame([[np.nan, 'dogs', 3]], index=fb.index)

# %%
# add year, month and day collumns extracted from time column
fb[["Year", "Month", "Day"]]= pd.DataFrame([fb["time"].apply(get_year_mon_day)],index=fb.index)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-116-e5f12995d8f9> in <module>()
#       1 # add year, month and day collumns extracted from time column
# ----> 2 fb[["Year", "Month", "Day"]]= pd.DataFrame([fb["time"].apply(get_year_mon_day)],index=fb.index)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     325
#     326                     mgr = _arrays_to_mgr(arrays, columns, index, columns,
# --> 327                                          dtype=dtype)
#     328                 else:
#     329                     mgr = self._init_ndarray(data, index, columns, dtype=dtype,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    5597
#    5598     # don't force copy because getting jammed in an ndarray anyway
# -> 5599     arrays = _homogenize(arrays, index, dtype)
#    5600
#    5601     # from BlockManager perspective
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _homogenize(data, index, dtype)
#    5908                 v = lib.fast_multiget(v, oindex.values, default=NA)
#    5909             v = _sanitize_array(v, index, dtype=dtype, copy=False,
# -> 5910                                 raise_cast_failure=False)
#    5911
#    5912         homogenized.append(v)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    3021             if len(subarr) != len(index) and len(subarr) == 1:
#    3022                 subarr = create_from_value(subarr[0], index,
# -> 3023                                            subarr.dtype)
#    3024
#    3025     elif subarr.ndim > 1:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in create_from_value(value, index, dtype)
#    2990             if not isinstance(dtype, (np.dtype, type(np.dtype))):
#    2991                 dtype = dtype.dtype
# -> 2992             subarr = np.empty(len(index), dtype=dtype)
#    2993             subarr.fill(value)
#    2994
#
# MemoryError:

# %%
a,b

# %%
fb.

# %%
fb["time"].nunique(
# Out:
# 1241

# %%
fb.corr()
# Out:
#                      dataset_id  checkins  were_here_count     likes  \
# dataset_id             1.000000  0.014284        -0.033538 -0.047131
# checkins               0.014284  1.000000         0.166944  0.052411
# were_here_count       -0.033538  0.166944         1.000000  0.256956
# likes                 -0.047131  0.052411         0.256956  1.000000
# talking_about_count   -0.031880  0.038259         0.065495  0.358866
# facebook_id            0.117912 -0.020870         0.077585  0.039388
# entity_id                   NaN       NaN              NaN       NaN
# cusip                       NaN       NaN              NaN       NaN
# isin                        NaN       NaN              NaN       NaN
#
#                      talking_about_count  facebook_id  entity_id  cusip  isin
# dataset_id                     -0.031880     0.117912        NaN    NaN   NaN
# checkins                        0.038259    -0.020870        NaN    NaN   NaN
# were_here_count                 0.065495     0.077585        NaN    NaN   NaN
# likes                           0.358866     0.039388        NaN    NaN   NaN
# talking_about_count             1.000000    -0.037722        NaN    NaN   NaN
# facebook_id                    -0.037722     1.000000        NaN    NaN   NaN
# entity_id                            NaN          NaN        NaN    NaN   NaN
# cusip                                NaN          NaN        NaN    NaN   NaN
# isin                                 NaN          NaN        NaN    NaN   NaN

# %%
datetime.strptime("2015-01-01","%Y, %m, %d")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-f8688d9e7151> in <module>()
# ----> 1 datetime.strptime("2015-01-01","%Y, %m, %d")
#
# C:\ProgramData\Anaconda3\lib\_strptime.py in _strptime_datetime(cls, data_string, format)
#     563     """Return a class cls instance based on the input string and the
#     564     format string."""
# --> 565     tt, fraction = _strptime(data_string, format)
#     566     tzname, gmtoff = tt[-2:]
#     567     args = tt[:6] + (fraction,)
#
# C:\ProgramData\Anaconda3\lib\_strptime.py in _strptime(data_string, format)
#     360     if not found:
#     361         raise ValueError("time data %r does not match format %r" %
# --> 362                          (data_string, format))
#     363     if len(data_string) != found.end():
#     364         raise ValueError("unconverted data remains: %s" %
#
# ValueError: time data '2015-01-01' does not match format '%Y, %m, %d'

# %%
"{%Y}".format(datetime.date(2015-01-01 05:00:00+00))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-13d54c93c1e0> in <module>()
# ----> 1 "{%Y}".format(datetime.date("2015-01-01 05:00:00+00"))
#
# TypeError: descriptor 'date' requires a 'datetime.datetime' object but received a 'str'

# %%
set(fb["username"])
# Out:
# {nan,
#  'PT6Nation',
#  'ListaInternational',
#  'winnebago',
#  'MedidataSolutions',
#  'attbusiness',
#  'vanguardengines',
#  'ShopVersona',
#  'SundanceTV',
#  'HawaiianAirlines',
#  'InfinitiTampa',
#  'NeenahFinePaper',
#  'MacatawaBank',
#  'GoCriteo',
#  'HDSupplyWhiteCap',
#  'ONEOKInc',
#  'SKYSITETechnologies',
#  'rejuvenationlightingandhouseparts',
#  'AppFolio',
#  'BrinksHomeSecurity',
#  'GoStorageUnits',
#  'TSYS1',
#  'leafchronicle',
#  'AstrotechCorp',
#  'hdsupplyfm',
#  'Dreft',
#  'ryanair',
#  'PlaneTechs',
#  'mosaiccompany',
#  'jose945',
#  'PolarisGov',
#  'HouseLogic',
#  'SMEnergy',
#  'geffenmedical',
#  'always',
#  'NordsonMARCH',
#  'HNNow',
#  'BBVAFrancesArg',
#  'Hologic',
#  'gamestopsuomi',
#  'WEtv',
#  'WisconsinStateJournal',
#  'hollister',
#  'AlliedMotion',
#  'gillette',
#  'CCCGlobal',
#  'CogginNissanAvenues',
#  'merrimackpharma',
#  'BRIDGENB',
#  'VideojetUS',
#  'PACCARFinancial',
#  'pioneeres',
#  'ValueLine',
#  'MoviePass',
#  'Chaco',
#  'PerkinElmer',
#  'catalystbio',
#  'Lasuavecita1043',
#  'AmeriSpecCorporate',
#  'patcatanstores',
#  'V8',
#  'JoMaloneLondon',
#  'AlugueTemporada',
#  'Gaiam',
#  'CarlisleSynTec',
#  'Microsoft',
#  'ISBBDO',
#  'BrooksAutomationInc',
#  'TheAxisAgency',
#  'MYOSRENSTechnology',
#  'ipower',
#  'deltadownscasino',
#  'southernrefrigeratedtransport',
#  'TaxACT',
#  'CalderCasino',
#  'sidestepshoes',
#  'WileyVCHVerlag',
#  'AerojetRdyne',
#  'FirstCitizensBankKY',
#  'foreign.policy.magazine',
#  'Anthropologie',
#  'weightwatchers',
#  'bikinidotcom',
#  'Kadant',
#  '1ShoppingCart',
#  'wynneverett',
#  'HotSpringSpas',
#  'ATTCareers',
#  'NissanofTampa',
#  'Enquirer',
#  'whirlpoolusa',
#  'NordsonASYMTEK',
#  'scsunnews',
#  'WernerEnterprisesInc',
#  'NxStage',
#  'rbc',
#  'Swanson',
#  'SkiHeavenly',
#  'GoogleSMB',
#  'SteelcaseEducation',
#  'TitanTireCorp',
#  'ManpowerUS',
#  'MaherComm',
#  'AlphaAdvancedMaterials',
#  'HondrosNursing',
#  'daVinciSurgery',
#  'LivePersonInc',
#  'grainger',
#  'athenahealth',
#  'amctheatres',
#  'MarineMaxDaytona',
#  'swiffer',
#  'TeradyneInc',
#  'Teva',
#  'surfexcelindia',
#  'Toro.Company',
#  'PDR.Network',
#  'EPAM.Global',
#  'badgermeter',
#  'formeonline',
#  'IFCFilmsOfficial',
#  'DonnaKaranNewYork',
#  'stitchfix',
#  'workhorsegroup',
#  'MotionInd',
#  'aptitopos',
#  'AmericanNationalHomeOffice',
#  'footaction',
#  'carefusion',
#  'WhollyGuacamole',
#  'SharpsCompliance',
#  'Marvel',
#  'ChillicotheGazette',
#  'universalhealthservices',
#  'DSW',
#  'TeamResellerClub',
#  'CatoFashions',
#  'covanta',
#  'thenorthface',
#  'norcraftcabinetry',
#  'Simonandschuster',
#  'ctrip.en',
#  'timesreporter',
#  'EnterpriseBank',
#  'GoogleGlass',
#  'manhattantvseries',
#  'HarteHanks',
#  'Callaway',
#  'POOLCORP1',
#  'CTGEurope',
#  'TheTownTalk',
#  'proteostasis',
#  'OreillyAutoParts',
#  'XeroxCorp',
#  'TiVo',
#  'Terrain',
#  'googleartsculture',
#  'PepsiCo',
#  'CNrail',
#  'RegencyCenters',
#  'realtor.com',
#  'ArielDetergente',
#  'BallCanning',
#  'atlantiscasinoresortspa',
#  'AshlandInc',
#  'siebertnet',
#  'EatGoodTimes',
#  'KirkwoodMtn',
#  'MarineMaxMinnesota',
#  'smithmicro',
#  'Amazon',
#  'acxiomcorp',
#  'Chuys.Restaurants',
#  'panoplynetwork',
#  'LaSaltenaArg',
#  '3MCollision',
#  'SpectraEnergy',
#  'Sequans',
#  'EagleBrand',
#  'FritoLay',
#  'Waverly',
#  'DailyLeader',
#  'GDMissionSystems',
#  'MichiganInsuranceCompany',
#  'Quaker',
#  'FirstMerchants',
#  'DrilQuipGlobal',
#  'FirstBusinessBank',
#  '21Club',
#  'birchlane',
#  'CambrexCorporation',
#  'assimumabrastemp',
#  'CTCAviation',
#  'bolthousefarms',
#  'sonoco.products',
#  'foxdeportes',
#  'TheTandD',
#  'TransActTech',
#  'RangeResourcesCorporation',
#  'fox43news',
#  'OffersDOTcom',
#  'PurdueGlobal',
#  'STMicroelectronics.NV',
#  'SKYSITEdocmanagement',
#  'MansfieldNewsJournal',
#  'LithiaMotors',
#  'heatbiologics',
#  'SevernSavingsBank',
#  '5StarSeniorLiving',
#  'MetaWellness1',
#  'bprox',
#  'erosnow',
#  'ESPN1650',
#  'Pears',
#  'HUEPPE.SHOWERANDSOUL',
#  'empiretribune',
#  'SiouxCityJournal',
#  'esabna',
#  'MIHomesInc',
#  'HumminbirdElectronics',
#  'cejkasearchinc',
#  'Philips',
#  'mresortspacasino',
#  'generacresidential',
#  'SikorskyAircraft',
#  'newellbrands',
#  'lehighoutfitters',
#  'elfcosmetics',
#  'NalleyINFINITIAtlanta',
#  'edgewaterfullscope',
#  'CourtesyPalmHarborHonda',
#  'KayJewelers',
#  'harristeeter',
#  'LatitudesDeck',
#  'propelwater',
#  'AvnetInc',
#  'avlcitizentimes',
#  'pkpbbdo',
#  'NUVOTupperware',
#  'bbdoportugal',
#  'EmerilsCooking',
#  'ownerscom',
#  'icadmed',
#  'IndependentBank',
#  'ymedialabsinc',
#  'LiveRamp',
#  'OtelcoInc',
#  'kcwy13',
#  'hot1035',
#  'krns6',
#  'timken',
#  'GentexCorporation',
#  'OwensCorning',
#  'Marshalls',
#  'NorthPointFordLincoln',
#  'KCMasterpiece',
#  'bettycrocker',
#  'AmanaBrand',
#  'Bloomingdales',
#  'Allegiant',
#  'VactorMfg',
#  'DEVRYUNIVERSITY',
#  'oxfordgolf',
#  'imperva',
#  'AuroraAdvertiser',
#  'CarlisleCW',
#  'calwater',
#  'jdpower',
#  'centennialbanking',
#  'GNC',
#  'tennessean',
#  'HDFC.bank',
#  'McKessonCorporation',
#  'OrchardSupplyHardware',
#  'HamburgReporter',
#  'autopartswarehouse',
#  'CUIGlobal',
#  'shophouse',
#  'proximitylondon',
#  'ABXAirInc',
#  'AmericanNationalAgribusinessInsurance',
#  'newscorp',
#  'EXFOInc',
#  'ExploreLearningReflex',
#  'statesmanjournal',
#  'theoakridger',
#  'TaylorDevices',
#  'eatsmartveggies',
#  'SevernBank',
#  'mobil1',
#  'glenrosereporter',
#  '247Sports',
#  'freestateandson',
#  'premierhealthcarealliance',
#  'CourtesyHyundaiTampa',
#  'onegasincorporated',
#  'RuthsChrisSteakHouseNational',
#  'MobankKC',
#  'VistaOutdoor',
#  'OneKingsLane',
#  'argusleader',
#  'PursuitAlaska',
#  'SandiaLabs',
#  'southjerseyenergy',
#  'Gmail',
#  'dallasyachting',
#  'SeaRayBoat',
#  'TildaRice',
#  'illuminainc',
#  'ConAgraFoods',
#  'silgancontainersllc',
#  'LeidosInc',
#  'skysiteconstructionapp',
#  'ufptechnologies',
#  'RevoSunglasses',
#  'FactSet',
#  'becca.cosmetics',
#  'NEWS7',
#  'FMCTI',
#  'GoldfishSmiles',
#  'thecapitalgrille',
#  'safeguardscientifics',
#  'Equifax',
#  'ManhattanWGNA',
#  'GTMBestPractices',
#  'cubiccorporation',
#  'duanereade',
#  'biospacecommunity',
#  'woodwardinc',
#  'kic',
#  'AlliantEnergyFoundation',
#  'MatrixMedicalNetwork',
#  'THORtravelservices',
#  'reliv',
#  'servicemaxinc',
#  '995themountain',
#  'poconorecord',
#  'Ultracargo',
#  'discover',
#  'StevensPointJRL',
#  'penumbraincmedtech',
#  'UnitedHealthcare',
#  'tomcatbrand',
#  'pinesol',
#  'AlimeraSciences',
#  'bargainadvocate',
#  'vonage',
#  'Winners',
#  'BetterOats',
#  'TheCW',
#  'MazorRobotics',
#  'BBDOUkraine',
#  'sgiglobal',
#  'hertz',
#  'ShawneeNewsStar',
#  'publicopinionnews',
#  'CTIBalloons',
#  'TheSpectrumNews',
#  'kolotv',
#  'braunshaversus',
#  'FirstMidwest',
#  'DeVryEducationGroup',
#  'DwellStudio',
#  'bestsourcemarketing1',
#  'Koss',
#  'MontanaStandard',
#  'BMOHarrisBank',
#  'pedialyte',
#  'supersavvyme',
#  'YvesVeggiePage',
#  'PlaySpeedyNinja',
#  'AlliantEnergy',
#  'ProteinSimple',
#  'alliancedata',
#  'santanderchile',
#  'ExploreLearningGizmos',
#  'gpstrategies',
#  'ChemicalBankCommunity',
#  'EvangelineDownsRacetrackCasino',
#  'LaneBryant',
#  'OmnicomGroupInc',
#  'Trappeys',
#  'SelectMedical',
#  'MagnaInternational',
#  'sportsmanswh',
#  'dentonrc',
#  'aboutdotcom',
#  'hilton',
#  'VITROAGENCY',
#  'BankUnited.Official',
#  'chuxproducts',
#  'MDSTF',
#  'RalphLauren',
#  'MolecularDevices',
#  'palitem',
#  'mrclean',
#  'MetroWestDailyNews',
#  'OldDominionFreightLine',
#  'NationstarMortgage',
#  'GameStopItalia',
#  'bbdoconnect',
#  'SBOnebank',
#  'grapenutscereal',
#  'DoritosUSA',
#  'PlayOverwatch',
#  'planetfitness',
#  'egglandsbesteggs',
#  'TheNew1037',
#  'makemytrip',
#  'Coloradoan',
#  'studiocitymacau',
#  'globalsiliconvalley',
#  'jessicasimpson',
#  '23WIFR',
#  'bancomacro',
#  'ClearanceJobs',
#  'BET',
#  'ubscareers',
#  'sears',
#  'CogginNissanAtlantic',
#  'madisongasandelectric',
#  'therecordheraldwaynesboro',
#  'WickedLocal',
#  'lacieworldwide',
#  'beef.ADM',
#  'GladiatorGW',
#  'shinhanlife',
#  'SEMAgency',
#  'randyjackson',
#  'BALI.Intimates',
#  'Lennox',
#  'radiodotcom',
#  'WestEndRoofingSupply',
#  'Ferrellgas',
#  'RotoRooter',
#  'LifeLock',
#  'columbiastatebank',
#  'ApplianceSmartUS',
#  'GameStop',
#  'LeMarsInsurance',
#  'CDWCorporation',
#  'MercerInsights',
#  'TelephoneandDataSystems',
#  'Inseego',
#  'ReginaVinegar',
#  'contrapuntobbdoespana',
#  'USGCORP',
#  'CapellaUniversity',
#  'KBSP.agency',
#  'CenturyLink',
#  'prinsautogassystemen',
#  'FEMSA',
#  'FamilyVacationCritic',
#  'marronebio',
#  'sobe',
#  'stjamesplaindealer',
#  'Teladoc',
#  'dailyadvertiser',
#  'randolphcountyheraldtribune',
#  'Mudd',
#  'SanminaCorp',
#  'FyponMillwork',
#  'RCJournal',
#  'Centexhomes',
#  'Vistaprint',
#  'Enzo.Life.Sciences',
#  'BellCanada',
#  'PineMountainFire',
#  'LandmarkNationalBank',
#  'skplanet',
#  'firstalertca',
#  'potbellysandwichshop',
#  'RavenAerostar',
#  'ATTSmallBiz',
#  'harvardapparatus',
#  'foxchasebank',
#  'VishayIntertechnology',
#  'YardHouse',
#  'BemisCompany',
#  'bancocredichile.cl',
#  'boyds',
#  'RAMCOproperties.rpt',
#  'SafetySignsService',
#  'CTGinc',
#  'Gordons',
#  'tkmaxx.at',
#  'cpsiehr',
#  'EASbrand',
#  'coastwaycommunitybank',
#  'HP',
#  'spokinc',
#  'hawaiiantropic',
#  'tractionuap',
#  'EmpenoFacilMexico',
#  'HowardBank1',
#  'Jos.A.Bank.Clothiers.Inc',
#  'aaronbrothers',
#  'thinkgeek',
#  'Amdocs',
#  'mtssystemscorp',
#  'RegisSalons',
#  'GlobalSelfStorageCorporate',
#  'MerryMaids',
#  'microsoftbi',
#  'MyNortheastBank',
#  'terrachips',
#  'journalandcourier',
#  'mopar',
#  'OceanFirstBank',
#  '2u',
#  'mountaindew',
#  'aol',
#  'RockyGap',
#  'Quanterix',
#  'navistar',
#  'elmirastargazette',
#  'theAlaskaCollection',
#  'craftsman',
#  'PlaytexSportandGentleGlide',
#  'HollywoodMVRC',
#  'MarinSoftware',
#  'Skintimate',
#  'MWBank',
#  'L3Communications',
#  'venmo',
#  'secret',
#  'kitchme',
#  'DestinationMat',
#  'cbsfilms',
#  'compugraphicsphotomasks',
#  'BradyCorporation',
#  'ArtsWaySci',
#  'DMNmediasolutions',
#  'PerdigaoOficial',
#  'sealymattress',
#  'WD',
#  'TopDressSupplements',
#  'bestbuy',
#  'FIStoday',
#  'GoDaddy',
#  'savingsinstitute',
#  'withKTgroup',
#  'spacelabshealthcare',
#  'radiojose1011',
#  'GE',
#  'MedicalStaffingNetwork',
#  'Costco',
#  'solarcity',
#  'WildcatMountain',
#  'bulletin.newsroom',
#  'hyvesolutions',
#  'PolarisRZR',
#  'jusroluk',
#  'MessengerPostMedia',
#  'WABCOvehiclecontrolsystems',
#  'kellyservices',
#  'HollywoodTunica',
#  'NalleyINFINITIMarietta',
#  'RedRobin',
#  'concordwatches',
#  'YouPuissantNaturellement',
#  'mediasite',
#  'Aonplc',
#  'UnitedFireGroup',
#  'HarleyDavidsonFootwear',
#  'OverlandStorage',
#  'carowindspark',
#  'Jose107.1',
#  'VisianICL',
#  'Pierce',
#  'cynthiarowleyny',
#  'HormelHealthLabs',
#  'schwinnfitness',
#  'EverfreshJuice',
#  'thehuddle',
#  'NeonodeTechnologies',
#  'SharpSpringInc',
#  'StellarBiotech',
#  'Bowflex',
#  'ProudToBeGenpact',
#  'palacestation',
#  'CelticHealthcare',
#  'LoewCornell',
#  'IRIDEX',
#  'StratasysDirectManufacturing',
#  'michaelfoods',
#  'LundBoats',
#  'TitanMachinery',
#  'pbteen',
#  'cebglobal',
#  'CanonMJ',
#  'NetApp',
#  'bancosantander',
#  'phl17',
#  'Broadwind',
#  'CATechnologies',
#  'AdventuresbyDisney',
#  'MealtimeMovement',
#  'AtlanticCapital',
#  'BerwickOffray',
#  'sharecare',
#  'FederalSignalFR',
#  'Fox59News',
#  'TKMaxxAustria',
#  'SodaStream',
#  'CogginOrangeParkBuickGMC',
#  'AmericanRiverBank',
#  'PortClintonNewsHerald',
#  'proximityprague',
#  'PolarisORV',
#  'GoogleArtProject',
#  'GranayMontero',
#  'AccurayIncorporated',
#  'RentACenter',
#  'provenmethod',
#  'Celanese',
#  'NUKUSA',
#  'ConcentrixCR',
#  'PALbyLantronix',
#  'Medaglia.dOro',
#  'KBRincorporated',
#  'MyriadGenetics',
#  'ServiceMaster',
#  'travelzoo',
#  'WrightMedical',
#  'peacecereal',
#  'BlackRock',
#  'YamanaGoldInc',
#  'greenworks',
#  'GarnierBBDO',
#  'Allpoint.Network',
#  'kumvtv',
#  'BakerDist',
#  'BradyNorthAmerica',
#  'yourALLDATAteam',
#  'sentrysafe',
#  'heartlandrv',
#  'BTUK',
#  'Gartner',
#  'godigitalmarketing',
#  'maranathanutbutters',
#  'Uncrustables',
#  'sonomapharma',
#  'hanoverinsurance',
#  'ultragazoficial',
#  'pgtwindowsdoors',
#  'Kwittken',
#  'elkodaily',
#  'MarineMaxGrandLake',
#  'RoofDepot',
#  'nteloswireless',
#  'NauticaUSA',
#  'ING',
#  'TakeShapeForLife',
#  'scegnews',
#  'MotorolaSolutions',
#  'Gentherm',
#  'Prudential',
#  'hubspot',
#  'Aussie',
#  'ETSLindgren',
#  'FederatedInvestors',
#  'EternalArena',
#  'DelWebbHomes',
#  'HeraldDispatch',
#  'mclartynissanlr',
#  'HeadwayCapital',
#  'KinderMorganInc',
#  'HannibalCourierPost',
#  'RidersByLee',
#  'ComfortSystemsUsa',
#  'WorldsofFun',
#  'Danskin',
#  'DarlingHomes',
#  'AndrewMarcLeather',
#  'avxcorp',
#  'OCCSolutions',
#  'ipass',
#  'RoadrunnerTransportation',
#  'FedEx',
#  'DesMoinesRegister',
#  'SherwinWilliamsforDesignersArchitects',
#  'domtarpaper',
#  'seaspine',
#  'remax',
#  'HealtheCareers',
#  'MedtronicCareers',
#  'stcloudtimes',
#  'longhornsteakhouse',
#  'arcdocumentsolutions',
#  'SynnexShareTheMagic',
#  'CambridgeChronicleIL',
#  'belomedia',
#  'RegionsBank',
#  'Justenergyfoundation',
#  'decbbdo',
#  'safetyinsurance',
#  'valleyfair',
#  'demingheadlight',
#  'ProDuoFrance',
#  'suntrust',
#  'KQCDtv',
#  'VoyaFinancial',
#  'Pioneerpump',
#  'ElevateCredit',
#  'NalleyLexusRoswell',
#  'edaptmscompany',
#  'LCNBNATBANK',
#  'ktla5',
#  'willisgroup',
#  'cree',
#  'petrovalveinc',
#  'RFMDMedia',
#  'blackbaud',
#  'AllyBank',
#  'CoreSite',
#  'ThinkONSemiconductor',
#  'braun',
#  'swingline',
#  'ConcentrixNI',
#  'Enomcom',
#  'pluralsight',
#  'JohnDeereUSCA',
#  '1stSourceBank',
#  'plainscapital',
#  'appcouples',
#  'MithunAgency',
#  'franklinfueling',
#  'taeqoficial',
#  'AvalonOrganics',
#  'InterSalonSallyBeauty',
#  'SusquehannaBank',
#  'WorkspringChicago',
#  'ResourcesGlobalProfessionals',
#  'pagoda',
#  'MilfordDailyNews',
#  'thetimesnews',
#  'OvaScience',
#  'LivinLite',
#  '99enterprises',
#  'Smiths',
#  'kuschall',
#  'roselandresidentialtrust',
#  'SOSClorox',
#  'SKIIUS',
#  'MoorMansShowTec',
#  'alliedhealthgroup',
#  'Resunate',
#  'firstbankwyoming',
#  'CogginBMWTreasureCoast',
#  'newsleaderStaunton',
#  'StJohnNewsKS',
#  'cmlauncher',
#  'AviatNet',
#  'WOLVERINE',
#  'mettlertoledo',
#  'chevrolet',
#  'AVLCitizenTimes',
#  'BancorpSouthStudents',
#  'muscatinejournal',
#  'Oncolytics.Biotech.Inc',
#  'VascularBiogenics',
#  '1011News',
#  'NukUSA',
#  'TrapperKeepers',
#  'goodneighborpharmacy',
#  'mhelpdesk',
#  'irobot',
#  'OrtegaTacos',
#  'ThorMotorCoach',
#  'Salsa981',
#  'HanfordSentinel',
#  'clearfieldinc',
#  'buyusedinventory',
#  'Cerner',
#  'FurnitureMedicCorporate',
#  'WaynesvilleDailyGuide',
#  'RiverviewBank',
#  'IDenticardSystems',
#  'McDonaldsUS',
#  'jinkosolar',
#  'NEWBlueSoHo',
#  'POOLCORP',
#  'DunBradstreet',
#  'progresssw',
#  'sincerelyinc',
#  'catfootwear',
#  'JASONPersonalCare',
#  'autozone',
#  'sandpglobal',
#  'WhiteHouseBlackMarket',
#  'rudisorganicbakery',
#  'NyQuil.DayQuil',
#  'SunbitesThailand',
#  'cosmoprofbeauty',
#  'farmerjohn',
#  'exelis',
#  'TheDowChemicalCompany',
#  'CVGRP',
#  'WashingtonTimesReporter',
#  'BHS',
#  'LincolnElectric',
#  'foxsports',
#  'GoogleDocs',
#  'mtshastanews',
#  'LaSuavecitaLasVegas',
#  'CommVault',
#  'NaEstradaComAIpiranga',
#  'f5networksinc',
#  'BankOfGreeneCounty',
#  'barnesandnoble',
#  'Cisco',
#  'Dr.ReddysLaboratoriesLtd',
#  'FirstFinancialBankNA',
#  'lgstxservices',
#  'aethlonmedical',
#  'PCGSCOIN',
#  'HomesteadWebsites',
#  'chasebrass',
#  'KILZBrand',
#  'deprisa',
#  'LinkedIn',
#  'MrTire',
#  'xfinity',
#  'mcneilusconcrete',
#  'PepsiUS',
#  'WellingtonDailyNews',
#  'carlislefsp',
#  'brancomotores',
#  'Activision',
#  'EFI.Digital.Print.Technology',
#  'therainbowcleaningsystem',
#  'showtime',
#  'LandstarSafety',
#  'ServiceMasterClean',
#  'beneficialbank',
#  'Doubletree',
#  'NalleyLexusGalleria',
#  'kiterealtygroup',
#  'SeacoastBank',
#  'Cheetos',
#  'cargurus',
#  'Bongo',
#  'bconnectedsocial',
#  'hrblock',
#  'chegg',
#  'MandTBank',
#  'lucy',
#  'flextronicsintl',
#  'AmegyBank',
#  'CarpenterTech',
#  'oshkoshcorporation',
#  'FLIR',
#  'HampshirePaper',
#  'CallawayPreOwned',
#  'VisteonCorporation',
#  'Agrowsil',
#  'towerjazz',
#  'courierpost',
#  'InnerWorkings',
#  'FiveStarBankNY',
#  'HaemoneticsCorp',
#  'eWeekNews',
#  'zimmer',
#  'attunity',
#  'BedBathAndBeyond',
#  'HeartlandLuxuryHomes',
#  'watchLOUD',
#  'sunpower',
#  'SoCoreEnergy',
#  'eskycoolers',
#  'SuperiorEnergy',
#  'OnStrideFinancial',
#  'Zillow',
#  'iiviinc',
#  'NVIDIA',
#  'WestElm',
#  'ProvidenceJournal',
#  'nordsonmedical',
#  'hormelvitalcuisine',
#  'OwensCorningRoofingandAsphalt',
#  'georgiaboot',
#  'EAS',
#  'witntv',
#  'westfieldbankma',
#  'EQTCorporation',
#  'iSharesETFs',
#  'AristaNW',
#  'RAPPWORLDWIDE',
#  'eatjaggers',
#  'UnitedOnline1',
#  'LaCroix',
#  'SimulationsPlus',
#  'cpbgroup',
#  'Citrix',
#  'PSAcard',
#  'fauquierbank',
#  'SailPoint',
#  'popular',
#  'BaxterInternationalInc',
#  'yahoo',
#  'generacpowersystems',
#  'EatSmartVeggies',
#  'hesscorporation',
#  'diamondjodubuque',
#  'Clorox',
#  'toplasticsinc',
#  'BoydGaming',
#  'siftingsherald',
#  'kidsfootlocker',
#  'usanahealthsciences',
#  'Norwegiancruiseline',
#  'ScholasticBookClubs',
#  'thrushexhaust',
#  'disneylandparis',
#  'AppianCorporation',
#  'jet',
#  'bonefishgrill',
#  'SnapNamesDotCom',
#  'microbotmedical',
#  'GameStopDACH',
#  'DEWALT',
#  'otiGlobal',
#  'WheelerREIT',
#  'OlinCareers',
#  'GeneralDynamicsIT',
#  'rushtruckcenters',
#  'MercuryComputerSystems',
#  'Internap',
#  'TwoRiverCommunityBank',
#  'lowes',
#  'americanaxle',
#  'carters',
#  'MasterLock',
#  'charmin',
#  'Southwest',
#  'wayfair',
#  'littleburgundyshoes',
#  'realfacesofdairy',
#  'Alarmdotcom',
#  'troveapp',
#  'StandardBrandParts',
#  'marinemaxlaketexomahighportmarina',
#  'ParADice',
#  'henryschein',
#  'spcapitaliq',
#  'Journeys',
#  'fox6news',
#  'aldiadallas',
#  'vailmtn',
#  'potterybarn',
#  'TandbergData',
#  'ParatekPharma',
#  'officialmmajunkie',
#  'imaginesoups',
#  'SabreCorporation',
#  'Phillips66Co',
#  'smithwessoncorp',
#  'VlasicStork',
#  'InformationServicesGroup',
#  'northwest',
#  'GaliciaSeguros',
#  'RnDSystems',
#  'fusionconnect',
#  'TimHortonsUS',
#  'UGGAustralia',
#  'FifthThirdBank',
#  'Luxoft',
#  'Insperity',
#  'Jose1071.1FM',
#  'Cutera',
#  'LauraScuddersPeanutButter',
#  'HMHTeen',
#  'PKUcom',
#  'colemanusa',
#  'Underarmour',
#  'sprint',
#  'risecredit',
#  'ChillicotheTimesBulletin',
#  'EnergyFocusInc',
#  'Macys',
#  'Carrabbas',
#  'SAP',
#  'AquaticaTexas',
#  'GreenDot',
#  'AppliedMaterialsInc',
#  'GNCLiveWell',
#  'Bojangles',
#  'lifetimefitness',
#  'Delawareonline',
#  'durangoboot',
#  'SeaWorld',
#  'ameliabellecasino',
#  'AmericanExpressUS',
#  'campaigneremail',
#  'GrandmasMolasses',
#  'ULTA',
#  'control4fans',
#  'boingo',
#  'scholasticparents',
#  ...}

# %%
ln[ln["company_name"].isin(inter)]["industry"].nunique()
# Out:
# 79

# %%
ln[ln["company_name"].isin(inter)]["industry"].unique()
# Out:
# array(['Information Technology and Services', 'Computer Networking',
#        'Electrical/Electronic Manufacturing', 'Internet',
#        'Mechanical or Industrial Engineering', 'Oil & Energy', 'Retail',
#        'Financial Services', 'Pharmaceuticals', 'Wireless',
#        'Computer Software', 'Banking', 'Computer Games',
#        'Food & Beverages', 'Defense & Space', 'Chemicals', 'Insurance',
#        'Restaurants', 'Package/Freight Delivery', 'Construction',
#        'Utilities', 'Automotive', 'Information Services',
#        'Facilities Services', 'Entertainment', 'Real Estate',
#        'Human Resources', 'Food Production', 'Computer Hardware',
#        'Computer & Network Security', 'Medical Devices',
#        'Health, Wellness and Fitness', 'Telecommunications',
#        'Semiconductors', 'Consumer Goods', nan, 'Consumer Electronics',
#        'Biotechnology', 'Hospital & Health Care', 'Music',
#        'Management Consulting', 'E-Learning',
#        'Security and Investigations', 'Consumer Services', 'Cosmetics',
#        'Education Management', 'Online Media', 'Outsourcing/Offshoring',
#        'Defense &amp; Space', 'Law Enforcement',
#        'Hospital &amp; Health Care', 'Oil &amp; Energy',
#        'Computer &amp; Network Security', 'Food &amp; Beverages',
#        'Airlines/Aviation', 'Renewables &amp; Environment',
#        'Renewables & Environment', 'Wholesale', 'Legal Services',
#        'Aviation &amp; Aerospace', 'Furniture', 'Mining &amp; Metals',
#        'Hospitality', 'Printing', 'Staffing and Recruiting', 'Warehousing',
#        'Higher Education', 'Motion Pictures and Film',
#        'Marketing and Advertising', 'Aviation & Aerospace',
#        'Mining & Metals', 'Building Materials', 'Environmental Services',
#        'Publishing', 'Textiles', 'Machinery', 'Apparel & Fashion',
#        'Design', 'Sporting Goods', 'Professional Training & Coaching'], dtype=object)

# %%
ln.corr()
# Out:
#                        dataset_id  followers_count  employees_on_platform  \
# dataset_id               1.000000        -0.235928              -0.272374
# followers_count         -0.235928         1.000000               0.729740
# employees_on_platform   -0.272374         0.729740               1.000000
# entity_id                     NaN              NaN                    NaN
# cusip                         NaN              NaN                    NaN
# isin                          NaN              NaN                    NaN
#
#                        entity_id  cusip  isin
# dataset_id                   NaN    NaN   NaN
# followers_count              NaN    NaN   NaN
# employees_on_platform        NaN    NaN   NaN
# entity_id                    NaN    NaN   NaN
# cusip                        NaN    NaN   NaN
# isin                         NaN    NaN   NaN

# %%
jb.head()

# %%
ln.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2426196 entries, 0 to 2426195
# Data columns (total 14 columns):
# dataset_id               int64
# as_of_date               object
# company_name             object
# followers_count          int64
# employees_on_platform    int64
# link                     object
# industry                 object
# date_added               object
# date_updated             object
# description              object
# website                  object
# entity_id                float64
# cusip                    float64
# isin                     float64
# dtypes: float64(3), int64(3), object(8)
# memory usage: 259.1+ MB

# %%
a=ln["company_name"].unique()
b= fb["username"].unique()

# %%
len(set(a)-set(b))
# Out:
# 4782

# %%
r={1,2}
r.intersection

# %%
len(set(a).intersection(set(b)))
# Out:
# 246

# %%
fb=pd.read_csv("temp_datalab_records_social_facebook.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
fb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3621391 entries, 0 to 3621390
# Data columns (total 14 columns):
# dataset_id             int64
# time                   object
# username               object
# checkins               int64
# has_added_app          object
# were_here_count        int64
# likes                  int64
# talking_about_count    int64
# facebook_id            int64
# date_added             object
# date_updated           object
# entity_id              float64
# cusip                  float64
# isin                   float64
# dtypes: float64(3), int64(6), object(5)
# memory usage: 386.8+ MB

# %%
fb["username"].nunique()
# Out:
# 4950

# %%
fb.corr()
# Out:
#                      dataset_id  checkins  were_here_count     likes  \
# dataset_id             1.000000  0.014284        -0.033538 -0.047131
# checkins               0.014284  1.000000         0.166944  0.052411
# were_here_count       -0.033538  0.166944         1.000000  0.256956
# likes                 -0.047131  0.052411         0.256956  1.000000
# talking_about_count   -0.031880  0.038259         0.065495  0.358866
# facebook_id            0.117912 -0.020870         0.077585  0.039388
# entity_id                   NaN       NaN              NaN       NaN
# cusip                       NaN       NaN              NaN       NaN
# isin                        NaN       NaN              NaN       NaN
#
#                      talking_about_count  facebook_id  entity_id  cusip  isin
# dataset_id                     -0.031880     0.117912        NaN    NaN   NaN
# checkins                        0.038259    -0.020870        NaN    NaN   NaN
# were_here_count                 0.065495     0.077585        NaN    NaN   NaN
# likes                           0.358866     0.039388        NaN    NaN   NaN
# talking_about_count             1.000000    -0.037722        NaN    NaN   NaN
# facebook_id                    -0.037722     1.000000        NaN    NaN   NaN
# entity_id                            NaN          NaN        NaN    NaN   NaN
# cusip                                NaN          NaN        NaN    NaN   NaN
# isin                                 NaN          NaN        NaN    NaN   NaN

# %%
fb.were_here_count.unique()
# Out:
# array([      0,     173,   46288, ...,  103379,  134857, 2976251], dtype=int64)

# %%
fb.time.head()[0]
# Out:
# '2015-01-01 05:00:00+00'

# %%
fb.groupby(["username", "time"])[]

# %%
datetime.time()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-7a536f562689> in <module>()
# ----> 1 datetime.time()
#
# TypeError: descriptor 'time' of 'datetime.datetime' object needs an argument
