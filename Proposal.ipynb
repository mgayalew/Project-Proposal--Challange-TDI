# %% [markdown]
# #  Insights from social media presence
#     Project Proposal for The Data Incubator Fellowship Program
#     By Muluemebet G Ayalew
#     Aug, 2019

# %%
import pandas as pd    # data exploration and manupulation  
import matplotlib.pyplot as plt  # for ploting 
import seaborn as sns            # for visualization 

# to see the plot in the notebook
% matplotlib inline

# %% [markdown]
# ## Read files

# %%
# facebook dataframe
fb =pd.read_csv("temp_datalab_records_social_facebook.zip", compression="zip")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#  linkedin dataframe
ln=pd.read_csv("temp_datalab_records_linkedin_company.zip", compression="zip")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ##  Data Exploration

# %% [markdown]
# ### Facebook

# %%
fb.shape # facebook dataframe shape
# Out:
# (3621391, 14)

# %%
fb.head()
# Out:
#    dataset_id                    time              username  checkins  \
# 0       53088  2015-01-01 05:00:00+00            SodaStream         0
# 1       52642  2015-01-01 05:00:00+00              ANSYSInc       148
# 2       53656  2015-01-01 05:00:00+00         MyAquaAmerica         0
# 3       53033  2015-01-01 05:00:00+00              Qualcomm       173
# 4       52783  2015-01-01 05:00:00+00  eaglepharmaceuticals         0
#
#   has_added_app  were_here_count    likes  talking_about_count  \
# 0             f                0   761533                  587
# 1             f                0    43442                 1305
# 2             f                0     5591                  297
# 3             f                0  1232521                 2685
# 4             f                0       18                    0
#
#         facebook_id date_added                   date_updated  entity_id  \
# 0       54885616308        NaN  2017-02-14 03:35:13.236826+00        NaN
# ...

# %%
fb.info() # info about facebook dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3621391 entries, 0 to 3621390
# Data columns (total 14 columns):
# dataset_id             int64
# time                   object
# username               object
# checkins               int64
# has_added_app          object
# were_here_count        int64
# likes                  int64
# talking_about_count    int64
# facebook_id            int64
# date_added             object
# date_updated           object
# entity_id              float64
# cusip                  float64
# isin                   float64
# dtypes: float64(3), int64(6), object(5)
# memory usage: 386.8+ MB

# %%
fb.username.nunique() # number of unique usernames in the dataframe
# Out:
# 4950

# %% [markdown]
# ### Linkedin

# %%
ln.shape # linkedin dataframe shape
# Out:
# (2426196, 14)

# %%
 ln.company_name.nunique() # number of unique companies in the dataframe
# Out:
# 5028

# %%
ln.head() # linkedin datafram
# Out:
#    dataset_id  as_of_date            company_name  followers_count  \
# 0       58329  2015-09-14           Goldman Sachs           552254
# 1       58329  2015-09-15           Goldman Sachs           552862
# 2       58363  2015-09-16     United Technologies            59157
# 3       58366  2015-09-16            Novo Nordisk           336175
# 4       58371  2015-09-16  Lowe's Companies, Inc.           134255
#
#    employees_on_platform                                   link  \
# 0                  38124  https://www.linkedin.com/company/1382
# 1                  38141  https://www.linkedin.com/company/1382
# 2                  14982  https://www.linkedin.com/company/2426
# 3                  26448  https://www.linkedin.com/company/2227
# 4                  62574  https://www.linkedin.com/company/4128
#
#                industry              date_added            date_updated  \
# 0    Investment Banking  2015-09-14 00:00:00+00  2015-09-14 00:00:00+00
# ...

# %%
ln.info() #info about linkedin dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2426196 entries, 0 to 2426195
# Data columns (total 14 columns):
# dataset_id               int64
# as_of_date               object
# company_name             object
# followers_count          int64
# employees_on_platform    int64
# link                     object
# industry                 object
# date_added               object
# date_updated             object
# description              object
# website                  object
# entity_id                float64
# cusip                    float64
# isin                     float64
# dtypes: float64(3), int64(3), object(8)
# memory usage: 259.1+ MB

# %%
print(ln.columns)
print(fb.columns)
# Out:
# Index(['dataset_id', 'as_of_date', 'company_name', 'followers_count',
#        'employees_on_platform', 'link', 'industry', 'date_added',
#        'date_updated', 'description', 'website', 'entity_id', 'cusip', 'isin'],
#       dtype='object')
# Index(['dataset_id', 'time', 'username', 'checkins', 'has_added_app',
#        'were_here_count', 'likes', 'talking_about_count', 'facebook_id',
#        'date_added', 'date_updated', 'entity_id', 'cusip', 'isin'],
#       dtype='object')

# %% [markdown]
# ##  Data Preparation :  Make the name case insensitive

# %%
# remove space from company name in linkedin dataframe to have similar format as facebook
lnname= ln.company_name.apply(lambda x: str(x).lower().replace(" ", ""))

# %%
lnname.head()
# Out:
# 0            goldmansachs
# 1            goldmansachs
# 2      unitedtechnologies
# 3             novonordisk
# 4    lowe'scompanies,inc.
# Name: company_name, dtype: object

# %%
ln.update(pd.DataFrame(lnname))  #update the naming format in the dataframe

# %%
ln.shape
# Out:
# (2426196, 14)

# %%
fbname=fb.username.apply(lambda x: str(x).lower()) # make the username into lowercase

# %%
fb["username"]=fbname

# %% [markdown]
# ## Data preparation : get similar date format

# %%
fb["time"].head() # time format in facebbook dataframe
# Out:
# 0    2015-01-01 05:00:00+00
# 1    2015-01-01 05:00:00+00
# 2    2015-01-01 05:00:00+00
# 3    2015-01-01 05:00:00+00
# 4    2015-01-01 05:00:00+00
# Name: time, dtype: object

# %%
ln.as_of_date.head() # linkedin date format
# Out:
# 0    2015-09-14
# 1    2015-09-15
# 2    2015-09-16
# 3    2015-09-16
# 4    2015-09-16
# Name: as_of_date, dtype: object

# %%
# to extract only the date part of time column of the facebook dataframe
def get_date(date):
    date=str(date) # convert to string
    splited=date.split(" ") #this separates date and time
    date=splited[0] # get the date
    return date

# %%
fb["DATE"]=fb["time"].apply(get_date) # the DATE collumn is created on facebook dataframe

# %% [markdown]
# ## Data Preparation :  Extract Year, Month and Day

# %%
#functions to extract year, month and day from column name "time" in  facebook dataframe 
def get_year(date):
    date= str(date) # convert to string 
    splited= date.split("-") # to get month, day, and year and time
    year= splited[0] # get year 
    return year

def get_month(date):
    date= str(date) # convert to string 
    splited= date.split("-") # to get month, day, and year and time
    month= splited[1] # get year 
    return month
def get_day(date):
    date= str(date) # convert to string 
    splited= date.split("-") # to get month, day, and year and time
    day= splited[2][:2] # extract only the day
    return day

# %%
ln.as_of_date.head()
# Out:
# 0    2015-09-14
# 1    2015-09-15
# 2    2015-09-16
# 3    2015-09-16
# 4    2015-09-16
# Name: as_of_date, dtype: object

# %%
# add year, month and day collumns extracted from time column
fb["Year"]= fb["time"].apply(get_year)

# %%
fb["Month"]= fb["time"].apply(get_month)
fb["Day"]=fb["time"].apply(get_day)

# %%
fb.columns
# Out:
# Index(['dataset_id', 'time', 'username', 'checkins', 'has_added_app',
#        'were_here_count', 'likes', 'talking_about_count', 'facebook_id',
#        'date_added', 'date_updated', 'entity_id', 'cusip', 'isin', 'DATE',
#        'Year', 'Month', 'Day'],
#       dtype='object')

# %%
fb.shape # four columns were added
# Out:
# (3621391, 18)

# %%
# convert year month and day into numeric
fb["Year"]= pd.to_numeric(fb["Year"])
fb["Month"]=pd.to_numeric(fb["Month"])
fb["Day"]=pd.to_numeric(fb["Day"])

# %% [markdown]
# ## Analyze Facebook Dataframe

# %%
def fb_statistics(name):
    '''The function that provides the date when a company ,its username is "name", was checkedin, 
    liked and people talked about it most; and displays the trend in a single graph  '''
    name=str(name)

    if name in fb["username"].values: # check if the username is in the dataframe
        fb_data=fb[fb["username"]==name]
         
       # plot the number of likes, checkins and talking about counts in a single graph
        fig =plt.figure(figsize=(14,20))
        
        # date vs numbers of likes 
        plt.subplot(5,1,1)
        plt.plot_date(fb_data["DATE"].values ,fb_data["likes"].values , "b-")
        plt.ylabel("Number of likes")
        
        # date vs numbers of checkins 
        plt.subplot(5,1,2)
        plt.plot_date(fb_data["DATE"].values ,fb_data["checkins"].values, "g-" )
        plt.ylabel("Number of checkins")
        
         # date vs talking_about_count
        plt.subplot(5,1,3)
        plt.plot_date(fb_data["DATE"].values ,fb_data["talking_about_count"].values, "r-")
        plt.ylabel("Talking_about_count")
        
        # date vs all
        plt.subplot(5,1,4)
        plt.plot_date(fb_data["DATE"].values ,fb_data["likes"].values , "b-")
        plt.plot_date(fb_data["DATE"].values ,fb_data["checkins"].values, "g-" )
        plt.plot_date(fb_data["DATE"].values ,fb_data["talking_about_count"].values, "r-")
        plt.legend(["likes", "checkins","talking_about"])
        plt.xlabel("Date")
        
        # month vs talking_about count
        plt.subplot(5,1,5)
        sns.boxplot(x="Month", y="talking_about_count", hue="Year", data=fb_data)
        plt.ylabel("Talking_about_count")
        plt.xlabel("Month")
        
        # fig.show()
        

        highest_like= fb_data[fb_data["likes"]==fb_data["likes"].max()][["DATE", "likes"]]
        highest_checkins= fb_data[fb_data["checkins"]==fb_data["checkins"].max()][["DATE", "checkins"]]
        highest_talking= fb_data[fb_data["talking_about_count"]==fb_data["talking_about_count"].max()][["DATE", "talking_about_count"]] 
       
        #print the text in bold and newline
        print("\n \033[1m" +"The following table shows the date when the highest likes, checkins and talking_about_counts were observed for "+ name.capitalize())
        
        return pd.concat((highest_like,highest_checkins,highest_talking), axis=0)
      
    else:
        print("Username not found! Please try a different username")

# %%
fb_statistics ("google")
# Out:
#  The following table shows the date when the highest likes, checkins and talking_about_counts were observed for Google
#                DATE  checkins       likes  talking_about_count
# 3617742  2018-07-16       NaN  26496281.0                  NaN
# 226343   2015-11-22  455244.0         NaN                  NaN
# 2890282  2017-12-20       NaN         NaN             683040.0

# %%
fb_statistics("ford") #  Ford company
# Out:
#  The following table shows the date when the highest likes, checkins and talking_about_counts were observed for Ford
#                DATE  checkins      likes  talking_about_count
# 3618029  2018-07-16       NaN  8869326.0                  NaN
# 3618029  2018-07-16   39524.0        NaN                  NaN
# 1313687  2016-12-16       NaN        NaN             214924.0

# %% [markdown]
# ## Companies both in facebook and linkedin

# %%
fbln_merge=pd.merge(fb,ln, left_on=["DATE","username"], right_on=["as_of_date","company_name"])

# %%
fbln_merge.sort_values(by=["username"])

# %%
fbln_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 515671 entries, 0 to 515670
# Data columns (total 32 columns):
# dataset_id_x             515671 non-null int64
# time                     515671 non-null object
# username                 515671 non-null object
# checkins                 515671 non-null int64
# has_added_app            515671 non-null object
# were_here_count          515671 non-null int64
# likes                    515671 non-null int64
# talking_about_count      515671 non-null int64
# facebook_id              515671 non-null int64
# date_added_x             379153 non-null object
# date_updated_x           515671 non-null object
# entity_id_x              0 non-null float64
# cusip_x                  0 non-null float64
# isin_x                   0 non-null float64
# DATE                     515671 non-null object
# Year                     515671 non-null object
# Month                    515671 non-null object
# Day                      515671 non-null object
# ...

# %%
#remove the following columns from the dataframe
fbln_merge.drop(["cusip_x", 'isin_x','cusip_y', 'isin_y' ], axis=1, inplace=True)

# %%
# datafram containing companies that are available in both fb and ln
lnfb= fb[(fb["username"].apply(lambda x: str(x).lower())).isin(lnname.values)]

# %%
fbln=fb[fb["username"].isin(lnname.values)]

# %%
lnfb.username.nunique()
# Out:
# 1026

# %%
lnfb=ln[ln.company_name.isin(fbname.values)]

# %%
fb["username"].nunique() # 4950

# %%
lnfb["username"].nunique() # 590

# %%
lnfb["username"].nunique() # after space removed and made case insensitive , we found 1026 companies both in fb and ln

# %%
ln.company_name.nunique() # 5028

# %%
ln.company_name.nunique()  # 5025 unique companies

# %% [markdown]
# ## who has the most followers on Linkedin - google

# %%
fbln_merge[fbln_merge.followers_count==fbln_merge.followers_count.max()] # google has the most followers
# Out:
#         dataset_id_x                    time username  checkins has_added_app  \
# 515003         62271  2018-07-16 04:00:00+00   google    410308             f
#
#         were_here_count     likes  talking_about_count   facebook_id  \
# 515003              480  26496281                94376  104958162837
#
#                          date_added_x     ...      company_name  \
# 515003  2018-07-17 05:25:51.475367+00     ...            google
#
#         followers_count employees_on_platform  \
# 515003          7825391                140543
#
#                                          link  industry  \
# 515003  https://www.linkedin.com/company/1441  Internet
#
#                          date_added_y                 date_updated_y  \
# 515003  2018-07-16 18:25:08.196282+00  2018-07-16 18:25:08.196329+00
#
#        description                website  entity_id_y
# 515003         NaN  http://www.google.com          NaN
#
# [1 rows x 28 columns]

# %%
#number of companies in each industry from merged dataframe
fbln_merge.groupby(by="industry")["company_name"].nunique().sort_values(ascending=False).head()
# Out:
# industry
# Banking                                100
# Computer Software                       69
# Information Technology and Services     60
# Retail                                  57
# Internet                                57
# Name: company_name, dtype: int64

# %% [markdown]
# ## Analyze Linkedin data

# %% [markdown]
# ### Which compnay  has the most followers in linkedin - google

# %%
ln[ln.followers_count==ln.followers_count.max()] # google has the most followrs on linkedin
# Out:
#          dataset_id  as_of_date company_name  followers_count  \
# 2424659       58448  2018-07-17       google          7833967
#
#          employees_on_platform                                   link  \
# 2424659                 140679  https://www.linkedin.com/company/1441
#
#          industry                     date_added  \
# 2424659  Internet  2018-07-17 16:03:54.273889+00
#
#                           date_updated description                website  \
# 2424659  2018-07-17 16:03:54.273916+00         NaN  http://www.google.com
#
#          entity_id  cusip  isin Month_l
# 2424659        NaN    NaN   NaN      07

# %%
# number of companies in each industry 
ln.groupby(by="industry")["company_name"].nunique().sort_values(ascending=False).head()
# Out:
# industry
# Biotechnology                          335
# Banking                                335
# Financial Services                     302
# Oil & Energy                           233
# Information Technology and Services    205
# Name: company_name, dtype: int64

# %% [markdown]
# ### Statistics about employee on platform by month and industry

# %%
ln["Month_l"]=ln.as_of_date.apply(get_month) # extract  the month

# %%
employee=pd.pivot_table(ln, index=["industry", "Month_l"] , values="employees_on_platform",aggfunc=("min","mean", "median", "max"))

# %%
employee
# Out:
#                                max          mean  median   min
# industry            Month_l
# Accounting          01        6778   1344.496689    27.0     0
#                     02        6986   1980.900000    28.0     0
#                     03        7065   6652.523077  6970.0     0
#                     04        7103   6871.671429  6998.5  5790
#                     05        7090   6653.695652  7000.5  5800
#                     06        7108   6641.170455  7003.0  5760
#                     07        7099   6542.807692  7009.5  5624
#                     08        7095   6426.655172  7081.5  5634
#                     09        7102   6446.237288  5920.0  5642
#                     10        7105   6309.793651  6245.0     0
#                     11        7070   2106.242268    28.0     0
#                     12        7065   1401.639456    28.0     0
# Airlines/Aviation   01       50558   9178.440617  2568.0    52
# ...

# %%
employee.loc["Banking"]["median"].plot()  # 
plt.xlabel("Month")
plt.ylabel("Employee_on_platform_count")
plt.title("Employee on platform for bank")

# %%
employee.loc["Investment Banking"]["median"].plot()  # 
plt.xlabel("Month")
plt.ylabel("Employee_on_platform_count")
plt.title("Employee on platform for Investment Banking")

# %%
employee.loc["Information Technology and Services"]["median"].plot()  # 
plt.xlabel("Month")
plt.ylabel("Employee_on_platform_count")
plt.title("Employee on platform for Information Technology and Services")

# %%
def ln_statistics(name):
    '''The function that provides the date when a company ,its username is "name", 
    had most followers count and employee on platform" ; and displays the trend in a single graph '''
    name=str(name)

    if name in ln["company_name"].values: # check if the name is in the dataframe
        ln_data=ln[ln["company_name"]==name]
         
       # plot the number of followers and imployee on platform  in a single graph
        fig, axes=plt.subplots(nrows=3, ncols=1, figsize=(12,9))
        axes[0].plot_date(ln_data["as_of_date"].values ,ln_data["followers_count"].values ,"b-")
        axes[0].set_ylabel("Number of followers")
                           
        
        axes[1].plot_date(ln_data["as_of_date"].values ,ln_data["employees_on_platform"].values, "r-" )
        axes[1].set_ylabel("Number of employee on platform")
        
        axes[2].plot_date(ln_data["as_of_date"].values ,ln_data["followers_count"].values ,"b-")
        axes[2].plot_date(ln_data["as_of_date"].values ,ln_data["employees_on_platform"].values, "r-" )
        axes[2].legend(["followers_count", "employees_on_platform"])
       
       # fig.show()
    
    else:
        print("Company name not found! Please try a different name")

# %%
ln_statistics("google")

# %% [markdown]
# ## who has the most likes on facebook

# %%
fb[fb.likes==fb.likes.max()]
# Out:
#          dataset_id                    time  username  checkins has_added_app  \
# 3617487       56196  2018-07-16 04:00:00+00  facebook        12             f
#
#          were_here_count      likes  talking_about_count  facebook_id  \
# 3617487           146272  210641077               761064  20531316728
#
#                            date_added                   date_updated  \
# 3617487  2018-07-17 05:25:30.93734+00  2018-07-17 05:25:30.937385+00
#
#          entity_id  cusip  isin        DATE  Year Month Day
# 3617487        NaN    NaN   NaN  2018-07-16  2018    07  16

# %%
fb_statistics("2u")
# Out:
#  The following table shows the date when the highest likes, checkins and talking_about_counts were observed for 2u
#                DATE  checkins   likes  talking_about_count
# 3617658  2018-07-16       NaN  5799.0                  NaN
# 3614347  2018-07-14    3271.0     NaN                  NaN
# 3617658  2018-07-16    3271.0     NaN                  NaN
# 3396455  2018-04-17       NaN     NaN               4469.0

# %%
ln_statistics("fordmotorcompany")
